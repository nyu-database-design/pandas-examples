# %% [markdown]
# # DataFrames in pandas
# A set of examples that exhibit some of the core features of the [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html) data type in the `pandas` module.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic concept
# A DataFrame is a two-dimensional tabular data struture.  It is easily visualized like a spreadsheet, with rows and columns.

# %%
# create a DataFrame from a dictionary containing labeled pandas Series
df = pd.DataFrame({
    'name': pd.Series( ['Foo', 'Bar', 'Baz'] ),
    'email': pd.Series( ['fo1258@foo.edu', 'br9876@foo.edu', 'bz2292@foo.edu'] ),
    'midterm exam': pd.Series( [99, 64, 87] ),
    'final exam': pd.Series( [94, 72, 81] )
})
df
# Out:
#   name           email  midterm exam  final exam
# 0  Foo  fo1258@foo.edu            99          94
# 1  Bar  br9876@foo.edu            64          72
# 2  Baz  bz2292@foo.edu            87          81

# %%
# get the DataFrame's schema
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          3 non-null      object
#  1   email         3 non-null      object
#  2   midterm exam  3 non-null      int64
#  3   final exam    3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes

# %% [markdown]
# ### Columns as Series
# Each column is a named `pandas` Series.

# %%
df['midterm exam']
# Out:
# 0    99
# 1    64
# 2    87
# Name: midterm exam, dtype: int64

# %%
# prove that a column of a DataFrame is a Series
type( df['midterm exam'] )
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Rows
# Each row is also considered a `pandas` Series.

# %%
# get a row by its index
df.loc[1]
# Out:
# name                       Bar
# email           br9876@foo.edu
# midterm exam                64
# final exam                  72
# Name: 1, dtype: object

# %%
# prove that a row of a DataFrame is a Series
type( df.loc[1] )
# Out:
# pandas.core.series.Series

# %%
# get a row by its integer index
df.iloc[2]
# Out:
# name                       Baz
# email           bz2292@foo.edu
# midterm exam                87
# final exam                  81
# Name: 2, dtype: object

# %% [markdown]
# ## Sorting

# %%
# sort by a column's value
df.sort_values(by='name', ascending=True)
# Out:
#   name           email  midterm exam  final exam
# 1  Bar  br9876@foo.edu            64          72
# 2  Baz  bz2292@foo.edu            87          81
# 0  Foo  fo1258@foo.edu            99          94

# %%
# add a new row with the same name as an existing row, but a different email
new_row = pd.Series({ 
    'name': 'Baz', 
    'email': 'bz2289@foo.edu',
    'midterm exam': 88,
    'final exam': 74
})

# append and automatically assign an index to new row
df = df.append(new_row, ignore_index=True) 

# sort by primary and secondary columns
df.sort_values(by=['name', 'email'], ascending=True)
# Out:
#   name           email  midterm exam  final exam
# 1  Bar  br9876@foo.edu            64          72
# 3  Baz  bz2289@foo.edu            88          74
# 2  Baz  bz2292@foo.edu            87          81
# 0  Foo  fo1258@foo.edu            99          94

# %%
# sort by index
df.sort_index(ascending=False)
# Out:
#   name           email  midterm exam  final exam
# 3  Baz  bz2289@foo.edu            88          74
# 2  Baz  bz2292@foo.edu            87          81
# 1  Bar  br9876@foo.edu            64          72
# 0  Foo  fo1258@foo.edu            99          94

# %% [markdown]
# ## Filtering rows

# %%
# match a criterion
df[ df['name'] == 'Bar' ]
# Out:
#   name           email  midterm exam  final exam
# 1  Bar  br9876@foo.edu            64          72

# %%
# match multiple criteria using & or | logic operators
df[ (df['name'] != 'Bar') & (df['midterm exam'] > 50) ]
# Out:
#   name           email  midterm exam  final exam
# 0  Foo  fo1258@foo.edu            99          94
# 2  Baz  bz2292@foo.edu            87          81
# 3  Baz  bz2289@foo.edu            88          74

# %% [markdown]
# ## Filtering columns

# %% [markdown]
# Extracting a **single column** is straightforward with square bracket syntax.

# %%
# fetch the 'name' column - this returns a Series
df['name']
# Out:
# 0    Foo
# 1    Bar
# 2    Baz
# 3    Baz
# Name: name, dtype: object

# %% [markdown]
# The easiest way to extract **multiple columns** from a dataframe is by supplying a list of column names.

# %%
# fetch the 'name' and 'final exam' columns - this returns a DataFrame
df[ ['name', 'final exam'] ]
# Out:
#   name  final exam
# 0  Foo          94
# 1  Bar          72
# 2  Baz          81
# 3  Baz          74

# %% [markdown]
# ## Filtering rows and columns

# %% [markdown]
# It is possible to use two sets of brackets to perform both row and column filters in one expression.

# %%
# find one row by its index, and fetch one column from the results - this returns a single value
df.loc[2]['final exam']
# Out:
# 81

# %%
# filter rows by criteria, and fetch one column from the results - this returns a Series
df[ df['name'] != 'Baz'][ 'name' ]
# Out:
# 0    Foo
# 1    Bar
# Name: name, dtype: object

# %%
# filter rows, and fetch multiple columns from the results - this returns a DataFrame
df[ df['name'] != 'Baz'][ ['name', 'midterm exam'] ]
# Out:
#   name  midterm exam
# 0  Foo            99
# 1  Bar            64

# %% [markdown]
# ## Basic operations

# %%
# give a flat 2% curve to all students on the midterm exam
# update the midterm exam column
df['midterm exam'] = df['midterm exam'] + 2
df
# Out:
#   name           email  midterm exam  final exam
# 0  Foo  fo1258@foo.edu           101          94
# 1  Bar  br9876@foo.edu            66          72
# 2  Baz  bz2292@foo.edu            89          81
# 3  Baz  bz2289@foo.edu            90          74

# %%
# add a new column to the dataframe...

# first, generate a Series of fake student ids
n_numbers = pd.Series(100000000 * np.random.random(4) ) # generate a series of random numbers
n_numbers = n_numbers.astype(int) # convert to a simple int to remove decimal place
n_numbers = 'N' + n_numbers.map(str) # add the letter 'N' in front of each number (first convert each to str)

# add to dataframe as a new column
df['n number'] = n_numbers
df
# Out:
#   name           email  midterm exam  final exam   n number
# 0  Foo  fo1258@foo.edu           101          94  N44178987
# 1  Bar  br9876@foo.edu            66          72  N76049874
# 2  Baz  bz2292@foo.edu            89          81    N311127
# 3  Baz  bz2289@foo.edu            90          74   N6761118

# %% [markdown]
# ## Merging two dataframes

# %%
# let's first create a second dataframe with some more information about each student
# note that one of the indices in this dataframe does not exist in the other dataframe
df2 = pd.DataFrame({
    'major': ['Math', 'Computer Science', 'Philosophy', 'Organic Gardening'],
    'minor': ['Art History', 'Linguistics', 'Music Performance', 'Theater Lighting']
}, index = [3, 0, 2, 1])

df2
# Out:
#                major              minor
# 3               Math        Art History
# 0   Computer Science        Linguistics
# 2         Philosophy  Music Performance
# 1  Organic Gardening   Theater Lighting

# %%
# do an "inner join" type merge, where referential integrity is maintained
df.join(df2)
# Out:
#   name           email  midterm exam  final exam   n number  \
# 0  Foo  fo1258@foo.edu           101          94  N89294433
# 1  Bar  br9876@foo.edu            66          72  N37799380
# 2  Baz  bz2292@foo.edu            89          81  N79937179
# 3  Baz  bz2289@foo.edu            90          74        NaN
#
#                major              minor
# 0   Computer Science        Linguistics
# 1  Organic Gardening   Theater Lighting
# 2         Philosophy  Music Performance
# 3               Math        Art History

# %%
# do a "left join" type merge, where referential integrity is not maintained
pd.concat( [df, df2], axis=1)
# Out:
#   name           email  midterm exam  final exam   n number  \
# 0  Foo  fo1258@foo.edu           101          94  N89294433
# 1  Bar  br9876@foo.edu            66          72  N37799380
# 2  Baz  bz2292@foo.edu            89          81  N79937179
# 3  Baz  bz2289@foo.edu            90          74        NaN
#
#                major              minor
# 0   Computer Science        Linguistics
# 1  Organic Gardening   Theater Lighting
# 2         Philosophy  Music Performance
# 3               Math        Art History

# %% [markdown]
# ## Setting the index
# It's possible to change which column is used as an index

# %%
# set the index to be the new n number
df.set_index('n number')
# Out:
#           name           email  midterm exam  final exam
# n number
# N44178987  Foo  fo1258@foo.edu           101          94
# N76049874  Bar  br9876@foo.edu            66          72
# N311127    Baz  bz2292@foo.edu            89          81
# N6761118   Baz  bz2289@foo.edu            90          74

# %% [markdown]
# ## Importing data from files
# Pandas can import from a variety of common data file formats, including CSV, JSON, fixed-width column text, and more.

# %%
# open data about NYC jobs from https://data.cityofnewyork.us/City-Government/NYC-Jobs/kpav-sd4t
df = pd.read_csv('./NYC_Jobs.csv')

# %%
# get the DataFrame's schema - notice the auto-detection of data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Job ID                         1218 non-null   int64
#  1   Agency                         1218 non-null   object
#  2   Posting Type                   1218 non-null   object
#  3   # Of Positions                 1218 non-null   int64
#  4   Business Title                 1218 non-null   object
#  5   Civil Service Title            1218 non-null   object
#  6   Title Classification           1218 non-null   object
#  7   Title Code No                  1218 non-null   object
#  8   Level                          1218 non-null   object
#  9   Job Category                   1216 non-null   object
#  10  Full-Time/Part-Time indicator  1129 non-null   object
#  11  Career Level                   1216 non-null   object
#  12  Salary Range From              1218 non-null   float64
#  13  Salary Range To                1218 non-null   float64
#  14  Salary Frequency               1218 non-null   object
#  15  Work Location                  1218 non-null   object
#  16  Division/Work Unit             1218 non-null   object
#  17  Job Description                1218 non-null   object
#  18  Minimum Qual Requirements      1198 non-null   object
#  19  Preferred Skills               1067 non-null   object
#  20  Additional Information         750 non-null    object
#  21  To Apply                       1215 non-null   object
#  22  Hours/Shift                    361 non-null    object
#  23  Work Location 1                485 non-null    object
#  24  Recruitment Contact            0 non-null      float64
#  25  Residency Requirement          1216 non-null   object
#  26  Posting Date                   1218 non-null   object
#  27  Post Until                     338 non-null    object
#  28  Posting Updated                1218 non-null   object
#  29  Process Date                   1218 non-null   object
# dtypes: float64(3), int64(2), object(25)
# memory usage: 285.6+ KB

# %%
# show a few randomly-sampled rows
df.sample(5)
# Out:
#       Job ID                          Agency Posting Type  # Of Positions  \
# 652   460690       OFFICE OF THE COMPTROLLER     Internal               1
# 395   427420                  LAW DEPARTMENT     Internal               2
# 286   457347     TAXI & LIMOUSINE COMMISSION     Internal               1
# 650   460630  DEPT OF ENVIRONMENT PROTECTION     External               1
# 1203  460632  DEPT OF ENVIRONMENT PROTECTION     External               1
#
#                            Business Title           Civil Service Title  \
# 652                        .NET Developer     COMPUTER ASSOC (SOFTWARE)
# 395         Facilities Building Custodian                     CUSTODIAN
# 286     Digital Communications Specialist  ASSOCIATE PUBLIC INFORMATION
# 650         2021-BEDC-001-BIM/CADD Intern         SUMMER COLLEGE INTERN
# 1203  2021-BEDC-002-Sustainability Intern         SUMMER COLLEGE INTERN
#
#      Title Classification Title Code No Level  \
# 652         Competitive-1         13631    03
# 395         Competitive-1         80609    02
# 286         Competitive-1         60816    02
# 650     Non-Competitive-5         10234    00
# 1203    Non-Competitive-5         10234    00
#
#                                     Job Category  ...  \
# 652                Technology, Data & Innovation  ...
# 395            Building Operations & Maintenance  ...
# 286   Communications & Intergovernmental Affairs  ...
# 650        Engineering, Architecture, & Planning  ...
# 1203       Engineering, Architecture, & Planning  ...
#
#                                  Additional Information  \
# 652                                                 NaN
# 395   Must file for the Custodian Civil Service Exam...
# 286                         Shift 11:00 am â 7:00 pm.
# 650   Please attach requested documents (writing sam...
# 1203                                                NaN
#
#                                                To Apply        Hours/Shift  \
# 652   TO APPLY: please visit our website at https://...                NaN
# 395                  Please click the Apply Now button.                NaN
# 286   Click, APPLY NOW Current city employees must a...                NaN
# 650   To Apply click the âApply Nowâ button  DEP...  35 Hours per week
# 1203  To Apply click the âApply Nowâ button  DEP...  35 Hours per week
#
#                                         Work Location 1 Recruitment Contact  \
# 652                                                 NaN                 NaN
# 395                                                 NaN                 NaN
# 286                           33 Beaver St, New York NY                 NaN
# 650   This position is located at 96-05 Horace Hardi...                 NaN
# 1203  This position is located at 96-05 Horace Hardi...                 NaN
#
#                                   Residency Requirement Posting Date  \
# 652   New York City Residency is not required for th...   04/01/2021
# 395   New York City residency is generally required ...   01/08/2020
# 286   New York City residency is generally required ...   01/22/2021
# 650   New York City residency is generally required ...   04/07/2021
# 1203  New York City residency is generally required ...   04/07/2021
#
#      Post Until Posting Updated Process Date
# 652         NaN      04/01/2021   04/13/2021
# 395         NaN      01/08/2020   04/13/2021
# 286         NaN      01/22/2021   04/13/2021
# 650         NaN      04/07/2021   04/13/2021
# 1203        NaN      04/07/2021   04/13/2021
#
# [5 rows x 30 columns]

# %%
# look for good-paying jobs ( > $200,000) available for external candidates
df_external_jobs = df[ df['Posting Type'] == 'External' ]
df_external_annual_jobs = df_external_jobs[ df_external_jobs['Salary Frequency'] == 'Annual' ]
df_external_annual_jobs_over_200k = df_external_annual_jobs[ df_external_annual_jobs['Salary Range To'] >= 200000 ]
df_external_annual_jobs_over_200k.sample(5)
# Out:
#      Job ID                        Agency Posting Type  # Of Positions  \
# 176  432041     ADMIN FOR CHILDREN'S SVCS     External               1
# 263  445754         NYC HOUSING AUTHORITY     External               1
# 734  441706   TAXI & LIMOUSINE COMMISSION     External               1
# 735  440527  NYC EMPLOYEES RETIREMENT SYS     External               1
# 759  373748  NYC EMPLOYEES RETIREMENT SYS     External               1
#
#                                         Business Title  \
# 176   Deputy Commissioner, Child and Family Well-Being
# 263      Vice President for Operation Support Services
# 734  General Counsel/Deputy Commissioner for Legal ...
# 735                  ADMINISTRATIVE MANAGEMENT AUDITOR
# 759                  ADMINISTRATIVE MANAGEMENT AUDITOR
#
#                 Civil Service Title Title Classification Title Code No Level  \
# 176  DEPUTY DIRECTOR OF ADMINISTRAT    Non-Competitive-5         52485    M7
# 263  ADMINISTRATIVE HOUSING SUPERIN        Competitive-1         10019    M5
# 734        EXECUTIVE AGENCY COUNSEL    Non-Competitive-5         95005    M6
# 735  ADMINISTRATIVE MANAGEMENT AUDI        Competitive-1         10010    M5
# 759  ADMINISTRATIVE MANAGEMENT AUDI        Competitive-1         10010    M7
#
#                                           Job Category  ...  \
# 176                                    Social Services  ...
# 263                  Building Operations & Maintenance  ...
# 734                                      Legal Affairs  ...
# 735                   Administration & Human Resources  ...
# 759  Administration & Human Resources Finance, Acco...  ...
#
#                                 Additional Information  \
# 176  Section 424-A of the New York Social Services ...
# 263  1.\tNYCHA employees applying for promotional, ...
# 734                                                NaN
# 735                                                NaN
# 759                                                NaN
#
#                                               To Apply  Hours/Shift  \
# 176                          Click on Apply Now button          NaN
# 263                        Click the Apply Now button.          NaN
# 734  Click, APPLY NOW Current city employees must a...          NaN
# 735  TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...          NaN
# 759  TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...          NaN
#
#                Work Location 1 Recruitment Contact  \
# 176                        NaN                 NaN
# 263                        NaN                 NaN
# 734  33 Beaver St, New York Ny                 NaN
# 735                        NaN                 NaN
# 759                        NaN                 NaN
#
#                                  Residency Requirement Posting Date  \
# 176  New York City residency is generally required ...   02/04/2020
# 263               NYCHA has no residency requirements.   09/23/2020
# 734  New York City residency is generally required ...   07/13/2020
# 735  New York City residency is generally required ...   06/24/2020
# 759  New York City residency is generally required ...   11/07/2018
#
#     Post Until Posting Updated Process Date
# 176        NaN      02/04/2020   04/13/2021
# 263        NaN      02/16/2021   04/13/2021
# 734        NaN      07/13/2020   04/13/2021
# 735        NaN      07/07/2020   04/13/2021
# 759        NaN      11/07/2018   04/13/2021
#
# [5 rows x 30 columns]

# %%
# the same query as above, just in one line
df[ (df['Posting Type'] == 'External') & (df['Salary Frequency'] == 'Annual') & (df['Salary Range To'] >= 200000) ].sample(5)
# Out:
#       Job ID                         Agency Posting Type  # Of Positions  \
# 369   459608   NYC EMPLOYEES RETIREMENT SYS     External               1
# 734   441706    TAXI & LIMOUSINE COMMISSION     External               1
# 993   458280       DEPARTMENT OF SANITATION     External               1
# 759   373748   NYC EMPLOYEES RETIREMENT SYS     External               1
# 1052  459311  OFFICE OF MANAGEMENT & BUDGET     External               1
#
#                                          Business Title  \
# 369   ADMINISTRATIVE RETIREMENT BENEFITS SPECIALIST,...
# 734   General Counsel/Deputy Commissioner for Legal ...
# 993   Deputy Director of Commercial Waste, Contracts...
# 759                   ADMINISTRATIVE MANAGEMENT AUDITOR
# 1052      Assistant Director  Administration of Justice
#
#                  Civil Service Title      Title Classification Title Code No  \
# 369   ADMINISTRATIVE RETIREMENT BENE             Competitive-1         82986
# 734         EXECUTIVE AGENCY COUNSEL         Non-Competitive-5         95005
# 993   ADMINISTRATIVE BUSINESS PROMOT             Competitive-1         10009
# 759   ADMINISTRATIVE MANAGEMENT AUDI             Competitive-1         10010
# 1052  BUDGET ANALYST (OMB)-MANAGERIA  Pending Classification-2         0608A
#
#      Level                                       Job Category  ...  \
# 369     M5                   Administration & Human Resources  ...
# 734     M6                                      Legal Affairs  ...
# 993     M4                 Finance, Accounting, & Procurement  ...
# 759     M7  Administration & Human Resources Finance, Acco...  ...
# 1052    M4  Finance, Accounting, & Procurement Policy, Res...  ...
#
#                                  Additional Information  \
# 369                                                 NaN
# 734                                                 NaN
# 993                                                 NaN
# 759                                                 NaN
# 1052  REQUIREMENTS:  Assistant Director ($141,766): ...
#
#                                                To Apply        Hours/Shift  \
# 369   TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...                NaN
# 734   Click, APPLY NOW Current city employees must a...                NaN
# 993   To apply, please submit resume and cover lette...  35 hours per week
# 759   TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...                NaN
# 1052  For City employees, please go to Employee Self...                NaN
#
#                      Work Location 1 Recruitment Contact  \
# 369                              NaN                 NaN
# 734        33 Beaver St, New York Ny                 NaN
# 993   125 Worth Street, New York, NY                 NaN
# 759                              NaN                 NaN
# 1052            255 Greenwich Street                 NaN
#
#                                   Residency Requirement Posting Date  \
# 369   New York City residency is generally required ...   03/15/2021
# 734   New York City residency is generally required ...   07/13/2020
# 993   New York City Residency is required within 90 ...   03/15/2021
# 759   New York City residency is generally required ...   11/07/2018
# 1052  New York City residency is generally required ...   03/10/2021
#
#      Post Until Posting Updated Process Date
# 369         NaN      03/15/2021   04/13/2021
# 734         NaN      07/13/2020   04/13/2021
# 993         NaN      03/16/2021   04/13/2021
# 759         NaN      11/07/2018   04/13/2021
# 1052        NaN      03/10/2021   04/13/2021
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Deal with missing values

# %%
# find any rows with missing values
bad_rows = df[ df.isnull().any(axis=1) ]
bad_rows.head(3)
# Out:
#    Job ID                        Agency Posting Type  # Of Positions  \
# 0  457043         NYC HOUSING AUTHORITY     Internal               1
# 1  231945     ADMIN FOR CHILDREN'S SVCS     Internal               9
# 2  456223  DEPT OF INFO TECH & TELECOMM     Internal               2
#
#                       Business Title       Civil Service Title  \
# 0              Chief Privacy Officer  EXECUTIVE AGENCY COUNSEL
# 1     Quality Improvement Specialist     COMMUNITY COORDINATOR
# 2  System Access Management Engineer    CYBER SECURITY ANALYST
#
#   Title Classification Title Code No Level  \
# 0    Non-Competitive-5         95005    M1
# 1    Non-Competitive-5         56058    00
# 2        Competitive-1         13633    01
#
#                                     Job Category  ...  \
# 0      Legal Affairs Policy, Research & Analysis  ...
# 1  Community & Business Services Social Services  ...
# 2                  Technology, Data & Innovation  ...
#
#                               Additional Information  \
# 0  1.\tNYCHA employees applying for promotional, ...
# 1  Section 424-A of the New York Social Services ...
# 2                                                NaN
#
#                                             To Apply  \
# 0                        Click the Apply Now button.
# 1                     Click on the Apply Now Button.
# 2  Special Note: Taking and passing civil service...
#
#                                          Hours/Shift  Work Location 1  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2  Day - Due to the necessary support duties of t...     Brooklyn, NY
#
#   Recruitment Contact                              Residency Requirement  \
# 0                 NaN               NYCHA has no residency requirements.
# 1                 NaN  New York City residency is generally required ...
# 2                 NaN  New York City residency is generally required ...
#
#   Posting Date   Post Until Posting Updated Process Date
# 0   02/05/2021  05-AUG-2021      02/05/2021   04/13/2021
# 1   02/26/2016          NaN      06/29/2016   04/13/2021
# 2   03/22/2021          NaN      03/22/2021   04/13/2021
#
# [3 rows x 30 columns]

# %%
# drop a few rows with missing data manually
new_df = df.drop( df.index[ [0, 1, 2] ] )

# look for missing values again
bad_rows = new_df[ new_df.isnull().any(axis=1) ]
bad_rows.head(3)
# Out:
#    Job ID                          Agency Posting Type  # Of Positions  \
# 3  460503  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 4  293033           NYC HOUSING AUTHORITY     External               1
# 5  451777       OFFICE OF THE COMPTROLLER     External               1
#
#                                       Business Title  \
# 3        2021-BWT-001-Construction Management Intern
# 4                             Deputy Press Secretary
# 5  Director - Diversity & Inclusion and Emerging ...
#
#               Civil Service Title Title Classification Title Code No Level  \
# 3           SUMMER COLLEGE INTERN    Non-Competitive-5         10234    00
# 4  ADMINISTRATIVE PUBLIC INFORMAT        Competitive-1         10033    M1
# 5  EXECUTIVE PROGRAM SPECIALIST (             Exempt-4         13390    M4
#
#                                  Job Category  ...  \
# 3       Engineering, Architecture, & Planning  ...
# 4  Communications & Intergovernmental Affairs  ...
# 5          Finance, Accounting, & Procurement  ...
#
#                               Additional Information  \
# 3                                                NaN
# 4  NYCHA employees applying for promotional, titl...
# 5  The selected candidate will be subject to the ...
#
#                                             To Apply        Hours/Shift  \
# 3  To Apply click the âApply Nowâ button  DEP...  35 Hours per week
# 4                        Click the Apply Now button.                NaN
# 5  Please visit our website at www.comptroller.ny...                NaN
#
#                                      Work Location 1 Recruitment Contact  \
# 3  This position is located at 96-05 Horace Hardi...                 NaN
# 4                                                NaN                 NaN
# 5                                                NaN                 NaN
#
#                                Residency Requirement Posting Date Post Until  \
# 3  New York City residency is generally required ...   04/07/2021        NaN
# 4               NYCHA has no residency requirements.   07/20/2017        NaN
# 5  New York City residency is generally required ...   10/29/2020        NaN
#
#   Posting Updated Process Date
# 3      04/07/2021   04/13/2021
# 4      08/02/2017   04/13/2021
# 5      02/11/2021   04/13/2021
#
# [3 rows x 30 columns]

# %%
# drop rows with any missing values
new_df.dropna()
# Out:
# Empty DataFrame
# Columns: [Job ID, Agency, Posting Type, # Of Positions, Business Title, Civil Service Title, Title Classification, Title Code No, Level, Job Category, Full-Time/Part-Time indicator, Career Level, Salary Range From, Salary Range To, Salary Frequency, Work Location, Division/Work Unit, Job Description, Minimum Qual Requirements, Preferred Skills, Additional Information, To Apply, Hours/Shift, Work Location 1, Recruitment Contact, Residency Requirement, Posting Date, Post Until, Posting Updated, Process Date]
# Index: []
#
# [0 rows x 30 columns]

# %%
# oops... we were too aggressive.  Let's drop just those rows with missing salary info
df = df.dropna(subset=['Salary Range From', 'Salary Range To'])
df.sample(3)
# Out:
#       Job ID                        Agency Posting Type  # Of Positions  \
# 897   460019             POLICE DEPARTMENT     Internal               1
# 1009  379095  NYC EMPLOYEES RETIREMENT SYS     Internal               2
# 584   442360  DEPARTMENT OF TRANSPORTATION     External               1
#
#                          Business Title             Civil Service Title  \
# 897   Senior Police Administrative Aide  SENIOR POLICE ADMINISTRATIVE A
# 1009     COMPUTER SPECIALIST (SOFTWARE)  COMPUTER SPECIALIST (SOFTWARE)
# 584                Diversity Specialist           COMMUNITY COORDINATOR
#
#      Title Classification Title Code No Level  \
# 897         Competitive-1         10147    00
# 1009        Competitive-1         13632    01
# 584     Non-Competitive-5         56058    00
#
#                           Job Category  ...  \
# 897   Administration & Human Resources  ...
# 1009     Technology, Data & Innovation  ...
# 584                      Legal Affairs  ...
#
#                                  Additional Information  \
# 897   This lateral opportunity is open to current Se...
# 1009                                                NaN
# 584                                                 NaN
#
#                                                To Apply  Hours/Shift  \
# 897   Please submit your resume and cover letter, an...          NaN
# 1009  TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...          NaN
# 584   All resumes are to be submitted electronically...          NaN
#
#                                         Work Location 1 Recruitment Contact  \
# 897   10th Precinct - 230 West 20th Street, New York...                 NaN
# 1009                                                NaN                 NaN
# 584                                      59 Maiden Lane                 NaN
#
#                                   Residency Requirement Posting Date  \
# 897   New York City residency is generally required ...   04/01/2021
# 1009  New York City Residency is not required for th...   01/08/2019
# 584   New York City residency is generally required ...   08/04/2020
#
#        Post Until Posting Updated Process Date
# 897   01-MAY-2021      04/01/2021   04/13/2021
# 1009          NaN      01/08/2019   04/13/2021
# 584   30-JUL-2021      02/12/2021   04/13/2021
#
# [3 rows x 30 columns]

# %%
# fill in missing values with zeros
df = df.fillna(0)
df.sample(3)
# Out:
#      Job ID                         Agency Posting Type  # Of Positions  \
# 900  458507     DEPT OF PARKS & RECREATION     Internal              40
# 302  460026  DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 883  424645  OFF OF PAYROLL ADMINISTRATION     Internal               1
#
#                                         Business Title  \
# 900                                 City Seasonal Aide
# 302  Associate Laboratory Microbiologist, Bureau of...
# 883                           Union Services Associate
#
#                 Civil Service Title Title Classification Title Code No Level  \
# 900              CITY SEASONAL AIDE    Non-Competitive-5         91406    00
# 302  ASSOCIATE LABORATORY MICROBIOL        Competitive-1         21514    01
# 883  PRINCIPAL ADMINISTRATIVE ASSOC        Competitive-1         10124    02
#
#                                           Job Category  ...  \
# 900                  Building Operations & Maintenance  ...
# 302                                             Health  ...
# 883  Finance, Accounting, & Procurement Policy, Res...  ...
#
#                                 Additional Information  \
# 900  THIS JOB VACANCY NOTICE IS ONLY FOR CITY SEASO...
# 302  **IMPORTANT NOTES TO ALL CANDIDATES:  Please n...
# 883                                                  0
#
#                                               To Apply  \
# 900  Please submit a cover letter and resume.  Park...
# 302  Apply online with a cover letter to https://a1...
# 883  Current NYC employees may apply to Job ID: 424...
#
#                  Hours/Shift                 Work Location 1  \
# 900                        0                           Bronx
# 302                        0                               0
# 883  35 Hours Week/Day Shift  5 Manhattan West, New York, NY
#
#     Recruitment Contact                              Residency Requirement  \
# 900                 0.0  Residency in New York City, Nassau, Orange, Ro...
# 302                 0.0         New York City residency is not required **
# 883                 0.0  New York City residency is generally required ...
#
#     Posting Date   Post Until Posting Updated Process Date
# 900   02/19/2021            0      04/06/2021   04/13/2021
# 302   03/30/2021  29-MAY-2021      03/30/2021   04/13/2021
# 883   12/03/2019            0      12/03/2019   04/13/2021
#
# [3 rows x 30 columns]

# %% [markdown]
# ## Basic statistics

# %%
# get an overview of most common stats
df.describe()
# Out:
#               Job ID  # Of Positions  Salary Range From  Salary Range To  \
# count    1218.000000     1218.000000        1218.000000      1218.000000
# mean   422305.477011        4.671593       54910.929420     80338.174449
# std     69258.267489       18.947981       33388.197579     52242.387389
# min     87990.000000        1.000000           0.000000        10.360000
# 25%    426293.750000        1.000000       38333.000000     55123.000000
# 50%    456028.000000        1.000000       58700.000000     78303.000000
# 75%    460054.500000        1.000000       74650.000000    108903.750000
# max    461151.000000      250.000000      250000.000000    265000.000000
#
#        Recruitment Contact
# count               1218.0
# mean                   0.0
# std                    0.0
# min                    0.0
# 25%                    0.0
# 50%                    0.0
# 75%                    0.0
# max                    0.0

# %%
# the same, but just for the 'Salary Range To' field (which is a Series, of course)
df['Salary Range To'].describe()
# Out:
# count      1218.000000
# mean      80338.174449
# std       52242.387389
# min          10.360000
# 25%       55123.000000
# 50%       78303.000000
# 75%      108903.750000
# max      265000.000000
# Name: Salary Range To, dtype: float64

# %%
# get just the mean from the column
df['Salary Range To'].median()
# Out:
# 78303.0

# %% [markdown]
# The other statistics functions - `min()`, `max()`, `mean()`, `std()`, `count()` - work similarly.

# %% [markdown]
# ## Count values
# The `value_counts()` function of a Series returns the number of times each value occurs.

# %%
df['Career Level'].value_counts()
# Out:
# Experienced (non-manager)    737
# Entry-Level                  183
# Manager                      176
# Student                      101
# Executive                     19
# 0                              2
# Name: Career Level, dtype: int64

# %%
df['Full-Time/Part-Time indicator'].value_counts()
# Out:
# F    1087
# 0      89
# P      42
# Name: Full-Time/Part-Time indicator, dtype: int64

# %% [markdown]
# ## Grouping by a column

# %%
# count how many jobs are in each agency
df.groupby("Agency")['Agency'].count()
# Out:
# Agency
# ADMIN FOR CHILDREN'S SVCS          55
# ADMIN TRIALS AND HEARINGS           4
# BOARD OF CORRECTION                 2
# BOROUGH PRESIDENT-QUEENS            2
# BUSINESS INTEGRITY COMMISSION       7
# CIVILIAN COMPLAINT REVIEW BD        2
# CONSUMER AFFAIRS                   34
# DEPARTMENT FOR THE AGING           16
# DEPARTMENT OF BUILDINGS             3
# DEPARTMENT OF BUSINESS SERV.        4
# DEPARTMENT OF CITY PLANNING        31
# DEPARTMENT OF CORRECTION           51
# DEPARTMENT OF INVESTIGATION        18
# DEPARTMENT OF PROBATION             6
# DEPARTMENT OF SANITATION            8
# DEPARTMENT OF TRANSPORTATION       12
# DEPT OF CITYWIDE ADMIN SVCS         9
# DEPT OF ENVIRONMENT PROTECTION    123
# DEPT OF HEALTH/MENTAL HYGIENE      85
# DEPT OF INFO TECH & TELECOMM       53
# DEPT OF PARKS & RECREATION         46
# DEPT OF YOUTH & COMM DEV SRVS      18
# DISTRICT ATTORNEY KINGS COUNTY      4
# DISTRICT ATTORNEY RICHMOND COU      4
# FINANCIAL INFO SVCS AGENCY         36
# FIRE DEPARTMENT                    14
# HOUSING PRESERVATION & DVLPMNT     36
# HRA/DEPT OF SOCIAL SERVICES        19
# HUMAN RIGHTS COMMISSION            24
# LAW DEPARTMENT                     67
# MANHATTAN COMMUNITY BOARD #6        2
# MANHATTAN COMMUNITY BOARD #7        2
# MAYORS OFFICE OF CONTRACT SVCS      4
# NYC EMPLOYEES RETIREMENT SYS       71
# NYC FIRE PENSION FUND               4
# NYC HOUSING AUTHORITY             134
# NYC POLICE PENSION FUND             6
# OFF OF PAYROLL ADMINISTRATION      17
# OFFICE OF COLLECTIVE BARGAININ      2
# OFFICE OF EMERGENCY MANAGEMENT     14
# OFFICE OF MANAGEMENT & BUDGET      30
# OFFICE OF THE COMPTROLLER          58
# POLICE DEPARTMENT                  50
# PRESIDENT BOROUGH OF MANHATTAN      2
# PUBLIC ADMINISTRATOR-NEW YORK       1
# TAXI & LIMOUSINE COMMISSION        23
# TEACHERS RETIREMENT SYSTEM          5
# Name: Agency, dtype: int64

# %%
# calculate the mean top salary within each agency
df.groupby("Agency")['Salary Range To'].mean()
# Out:
# Agency
# ADMIN FOR CHILDREN'S SVCS          96378.202182
# ADMIN TRIALS AND HEARINGS          18905.576350
# BOARD OF CORRECTION               150000.000000
# BOROUGH PRESIDENT-QUEENS           63794.000000
# BUSINESS INTEGRITY COMMISSION      87857.142857
# CIVILIAN COMPLAINT REVIEW BD      108064.500000
# CONSUMER AFFAIRS                   69002.576471
# DEPARTMENT FOR THE AGING           79165.859337
# DEPARTMENT OF BUILDINGS            74076.666667
# DEPARTMENT OF BUSINESS SERV.      137641.750000
# DEPARTMENT OF CITY PLANNING        77604.548387
# DEPARTMENT OF CORRECTION           76070.957784
# DEPARTMENT OF INVESTIGATION        76121.888889
# DEPARTMENT OF PROBATION            62702.333333
# DEPARTMENT OF SANITATION          143626.850000
# DEPARTMENT OF TRANSPORTATION      115114.530000
# DEPT OF CITYWIDE ADMIN SVCS        57031.733333
# DEPT OF ENVIRONMENT PROTECTION     31538.537340
# DEPT OF HEALTH/MENTAL HYGIENE      70782.981556
# DEPT OF INFO TECH & TELECOMM      145506.735849
# DEPT OF PARKS & RECREATION          6190.519243
# DEPT OF YOUTH & COMM DEV SRVS      85150.333333
# DISTRICT ATTORNEY KINGS COUNTY     52544.000000
# DISTRICT ATTORNEY RICHMOND COU     99808.000000
# FINANCIAL INFO SVCS AGENCY         95381.533333
# FIRE DEPARTMENT                    75128.203029
# HOUSING PRESERVATION & DVLPMNT     78854.944444
# HRA/DEPT OF SOCIAL SERVICES        82291.315789
# HUMAN RIGHTS COMMISSION            87598.416667
# LAW DEPARTMENT                     69019.732512
# MANHATTAN COMMUNITY BOARD #6       52000.000000
# MANHATTAN COMMUNITY BOARD #7      100000.000000
# MAYORS OFFICE OF CONTRACT SVCS    118550.000000
# NYC EMPLOYEES RETIREMENT SYS      131359.198963
# NYC FIRE PENSION FUND             156076.000000
# NYC HOUSING AUTHORITY              85354.854776
# NYC POLICE PENSION FUND            65373.000000
# OFF OF PAYROLL ADMINISTRATION      53971.934118
# OFFICE OF COLLECTIVE BARGAININ        10.360000
# OFFICE OF EMERGENCY MANAGEMENT     90750.000000
# OFFICE OF MANAGEMENT & BUDGET     101379.666667
# OFFICE OF THE COMPTROLLER          95235.505862
# POLICE DEPARTMENT                  73680.579200
# PRESIDENT BOROUGH OF MANHATTAN    100000.000000
# PUBLIC ADMINISTRATOR-NEW YORK      49349.000000
# TAXI & LIMOUSINE COMMISSION       103237.086957
# TEACHERS RETIREMENT SYSTEM         97400.000000
# Name: Salary Range To, dtype: float64

# %%
# show just the top 10 paying agencies
df.groupby("Agency")['Salary Range To'].mean().sort_values().tail(10)
# Out:
# Agency
# TAXI & LIMOUSINE COMMISSION       103237.086957
# CIVILIAN COMPLAINT REVIEW BD      108064.500000
# DEPARTMENT OF TRANSPORTATION      115114.530000
# MAYORS OFFICE OF CONTRACT SVCS    118550.000000
# NYC EMPLOYEES RETIREMENT SYS      131359.198963
# DEPARTMENT OF BUSINESS SERV.      137641.750000
# DEPARTMENT OF SANITATION          143626.850000
# DEPT OF INFO TECH & TELECOMM      145506.735849
# BOARD OF CORRECTION               150000.000000
# NYC FIRE PENSION FUND             156076.000000
# Name: Salary Range To, dtype: float64

# %%
# find agencies with the largest range of salaries
df['Salary Range'] = df['Salary Range To'] - df['Salary Range From']
df.groupby("Agency")['Salary Range'].mean().sort_values().tail(10)[::-1]
# Out:
# Agency
# DISTRICT ATTORNEY RICHMOND COU    99808.000000
# DEPARTMENT OF SANITATION          92479.280000
# NYC FIRE PENSION FUND             90707.000000
# DEPARTMENT OF BUSINESS SERV.      82505.500000
# DEPT OF INFO TECH & TELECOMM      81912.075472
# DEPARTMENT OF TRANSPORTATION      62526.250000
# CIVILIAN COMPLAINT REVIEW BD      59884.500000
# NYC EMPLOYEES RETIREMENT SYS      52422.800256
# TAXI & LIMOUSINE COMMISSION       35955.173913
# NYC HOUSING AUTHORITY             33264.017910
# Name: Salary Range, dtype: float64

# %% [markdown]
# ## Shape

# %%
# how many rows and columns?
df.shape
# Out:
# (1218, 30)

# %%
# remind ourselves of the look of the data
df.sample(3)
# Out:
#       Job ID                         Agency Posting Type  # Of Positions  \
# 694   434073  DEPT OF YOUTH & COMM DEV SRVS     Internal               1
# 178   424227     FINANCIAL INFO SVCS AGENCY     Internal               1
# 1025  444520    DEPARTMENT OF INVESTIGATION     Internal               1
#
#                     Business Title             Civil Service Title  \
# 694   Cornerstone Program Director  ADMIN COMMUNITY RELATIONS SPEC
# 178      Web Application Developer             SENIOR IT ARCHITECT
# 1025          Director of Outreach            SPECIAL INVESTIGATOR
#
#      Title Classification Title Code No Level  \
# 694         Competitive-1         1002F    00
# 178     Non-Competitive-5         95711    00
# 1025             Exempt-4         31130    00
#
#                                            Job Category  ...  \
# 694           Constituent Services & Community Programs  ...
# 178                       Technology, Data & Innovation  ...
# 1025  Communications & Intergovernmental Affairs Pol...  ...
#
#                                  Additional Information  \
# 694   This position is open to qualified persons wit...
# 178                                                P293
# 1025                                                NaN
#
#                                                To Apply  \
# 694   Search for the Job ID # 434073 External Candid...
# 178   External applicants please visit https://a127-...
# 1025  All current City Employees may apply by going ...
#
#                         Hours/Shift  Work Location 1 Recruitment Contact  \
# 694     35 Hours Per Week (minimum)              NaN                 NaN
# 178   Monday - Friday, 9am  to 5pm.              NaN                 NaN
# 1025                            NaN  180 Maiden Lane                 NaN
#
#                                   Residency Requirement Posting Date  \
# 694   New York City residency is generally required ...   02/21/2020
# 178   New York City Residency is not required for th...   11/27/2019
# 1025  New York City residency is generally required ...   09/14/2020
#
#        Post Until Posting Updated Process Date
# 694           NaN      02/21/2020   04/13/2021
# 178           NaN      11/27/2019   04/13/2021
# 1025  30-JUN-2021      03/10/2021   04/13/2021
#
# [3 rows x 30 columns]

# %%
# flip the dataframe so columns become rows and rows become columns
df.transpose().head()
# Out:
#                                  0                               1     \
# Job ID                         457043                          231945
# Agency          NYC HOUSING AUTHORITY       ADMIN FOR CHILDREN'S SVCS
# Posting Type                 Internal                        Internal
# # Of Positions                      1                               9
# Business Title  Chief Privacy Officer  Quality Improvement Specialist
#
#                                              2     \
# Job ID                                     456223
# Agency               DEPT OF INFO TECH & TELECOMM
# Posting Type                             Internal
# # Of Positions                                  2
# Business Title  System Access Management Engineer
#
#                                                        3     \
# Job ID                                               460503
# Agency                       DEPT OF ENVIRONMENT PROTECTION
# Posting Type                                       Internal
# # Of Positions                                            1
# Business Title  2021-BWT-001-Construction Management Intern
#
#                                   4     \
# Job ID                          293033
# Agency           NYC HOUSING AUTHORITY
# Posting Type                  External
# # Of Positions                       1
# Business Title  Deputy Press Secretary
#
#                                                              5     \
# Job ID                                                     451777
# Agency                                  OFFICE OF THE COMPTROLLER
# Posting Type                                             External
# # Of Positions                                                  1
# Business Title  Director - Diversity & Inclusion and Emerging ...
#
#                                           6                           7     \
# Job ID                                  458663                      458506
# Agency          PRESIDENT BOROUGH OF MANHATTAN  DEPT OF PARKS & RECREATION
# Posting Type                          Internal                    Internal
# # Of Positions                               1                          60
# Business Title  Information Technology Manager          City Seasonal Aide
#
#                                       8                            9     ...  \
# Job ID                              458506                       460791  ...
# Agency          DEPT OF PARKS & RECREATION   FINANCIAL INFO SVCS AGENCY  ...
# Posting Type                      Internal                     Internal  ...
# # Of Positions                          60                            1  ...
# Business Title          City Seasonal Aide  MAINFRAME SYSTEM PROGRAMMER  ...
#
#                                                      1208  \
# Job ID                                             316149
# Agency                              NYC HOUSING AUTHORITY
# Posting Type                                     External
# # Of Positions                                          5
# Business Title  Construction Safety and Quality Inspector
#
#                                     1209                          1210  \
# Job ID                            432393                        445338
# Agency          DEPARTMENT OF CORRECTION  DEPT OF INFO TECH & TELECOMM
# Posting Type                    External                      Internal
# # Of Positions                         5                             5
# Business Title              EXTERMINATOR   Cyber Senior Threat Anaylst
#
#                                                          1211  \
# Job ID                                                 395999
# Agency                                         LAW DEPARTMENT
# Posting Type                                         Internal
# # Of Positions                                              1
# Business Title  Certified IT Developer (Applications) Level 3
#
#                                                          1212  \
# Job ID                                                 395999
# Agency                                         LAW DEPARTMENT
# Posting Type                                         Internal
# # Of Positions                                              1
# Business Title  Certified IT Developer (Applications) Level 3
#
#                                        1213                       1214  \
# Job ID                               456344                     237576
# Agency          HRA/DEPT OF SOCIAL SERVICES  ADMIN FOR CHILDREN'S SVCS
# Posting Type                       External                   Internal
# # Of Positions                           10                          1
# Business Title    CRISIS INTERVENTION NURSE     Deputy Budget Director
#
#                            1215                                1216  \
# Job ID                   458965                              454766
# Agency          FIRE DEPARTMENT            DEPARTMENT OF SANITATION
# Posting Type           External                            Internal
# # Of Positions                1                                   1
# Business Title     PSYCHOLOGIST  DIRECTOR, EMPLOYEE ASSISTANCE UNIT
#
#                              1217
# Job ID                     448861
# Agency          POLICE DEPARTMENT
# Posting Type             External
# # Of Positions                  1
# Business Title  Elevator Mechanic
#
# [5 rows x 1218 columns]
