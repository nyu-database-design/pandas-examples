# %%
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/site-packages (1.24.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: /usr/local/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: /usr/local/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip

# %% [markdown]
# # DataFrames in pandas
# A set of examples that exhibit some of the core features of the [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html) data type in the `pandas` module.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic concept
# A DataFrame is a two-dimensional tabular data struture.  It is easily visualized like a spreadsheet, with rows and columns.

# %%
# create a DataFrame from a dictionary containing labeled pandas Series
df = pd.DataFrame({
    'name': pd.Series( ['Foo', 'Bar', 'Baz', 'Bum', 'Buddle'] ),
    'email': pd.Series( ['fo1258@foo.edu', 'br9876@foo.edu', 'bz2292@foo.edu', 'bm4567@foo.edu', 'bp987@foo.edu'] ),
    'midterm exam': pd.Series( [99, 64, 87, 64, 72] ),
    'final exam': pd.Series( [94, 72, 81, 59, 88] )
})
df
# Out:
#      name           email  midterm exam  final exam
# 0     Foo  fo1258@foo.edu            99          94
# 1     Bar  br9876@foo.edu            64          72
# 2     Baz  bz2292@foo.edu            87          81
# 3     Bum  bm4567@foo.edu            64          59
# 4  Buddle   bp987@foo.edu            72          88

# %%
# get the DataFrame's schema
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          5 non-null      object
#  1   email         5 non-null      object
#  2   midterm exam  5 non-null      int64
#  3   final exam    5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %% [markdown]
# ### Columns as Series
# Each column is a named `pandas` Series.

# %% [markdown]
# To access a single column, simply supply the column's name.

# %%
df['midterm exam']
# Out:
# 0    99
# 1    64
# 2    87
# 3    64
# 4    72
# Name: midterm exam, dtype: int64

# %% [markdown]
# To access multiple columns, supply a list of the column names.

# %%
df[ ['name', 'midterm exam'] ]
# Out:
#      name  midterm exam
# 0     Foo            99
# 1     Bar            64
# 2     Baz            87
# 3     Bum            64
# 4  Buddle            72

# %%
# prove that a column of a DataFrame is a Series
type( df[['midterm exam', 'final exam'] ] )
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Create a new column by assigning it a series as a value.

# %%
# let's create an 'overall score' column that is 40% the midterm score + 60% the final exam score.
df['overall score'] = 0.4*df['midterm exam'] + 0.6*df['final exam']
df
# Out:
#      name           email  midterm exam  final exam  overall score
# 0     Foo  fo1258@foo.edu            99          94           96.0
# 1     Bar  br9876@foo.edu            64          72           68.8
# 2     Baz  bz2292@foo.edu            87          81           83.4
# 3     Bum  bm4567@foo.edu            64          59           61.0
# 4  Buddle   bp987@foo.edu            72          88           81.6

# %%
# generate a comment column explaining the scores in nice friendly human language.
# set axis=1 to have the lambda function receive columns as its argument
df['comment'] = df.apply(lambda row: "Your overall score in the course is " + str(row['overall score']), axis=1 )
df
# Out:
#      name           email  midterm exam  final exam  overall score  \
# 0     Foo  fo1258@foo.edu            99          94           96.0
# 1     Bar  br9876@foo.edu            64          72           68.8
# 2     Baz  bz2292@foo.edu            87          81           83.4
# 3     Bum  bm4567@foo.edu            64          59           61.0
# 4  Buddle   bp987@foo.edu            72          88           81.6
#
#                                     comment
# 0  Your overall score in the course is 96.0
# 1  Your overall score in the course is 68.8
# 2  Your overall score in the course is 83.4
# 3  Your overall score in the course is 61.0
# 4  Your overall score in the course is 81.6

# %% [markdown]
# ## Rows
# Each row is also considered a `pandas` Series.

# %%
# get a row by its index
df.loc[1]
# Out:
# name                                                  Bar
# email                                      br9876@foo.edu
# midterm exam                                           64
# final exam                                             72
# overall score                                        68.8
# comment          Your overall score in the course is 68.8
# Name: 1, dtype: object

# %%
# prove that a row of a DataFrame is a Series
type( df.loc[1] )
# Out:
# pandas.core.series.Series

# %%
# get a row by its integer index (this works even when the indices are strings)
df.iloc[2]
# Out:
# name                                                  Baz
# email                                      bz2292@foo.edu
# midterm exam                                           87
# final exam                                             81
# overall score                                        83.4
# comment          Your overall score in the course is 83.4
# Name: 2, dtype: object

# %% [markdown]
# Get multiple rows by supplying a list of integer indices:

# %%
df.iloc[ [1, 2]  ]
# Out:
#   name           email  midterm exam  final exam  overall score  \
# 1  Bar  br9876@foo.edu            64          72           68.8
# 2  Baz  bz2292@foo.edu            87          81           83.4
#
#                                     comment
# 1  Your overall score in the course is 68.8
# 2  Your overall score in the course is 83.4

# %% [markdown]
# Get multiple rows by supplying a range

# %%
df.iloc[ 1:3 ] # exclusive of index #3
# Out:
#   name           email  midterm exam  final exam  overall score  \
# 1  Bar  br9876@foo.edu            64          72           68.8
# 2  Baz  bz2292@foo.edu            87          81           83.4
#
#                                     comment
# 1  Your overall score in the course is 68.8
# 2  Your overall score in the course is 83.4

# %% [markdown]
# Note that the same range, when using `loc` instead of `iloc`, will be inclusive of the upper bound:

# %%
df.loc[ 1:3 ] # inclusive of index #3
# Out:
#   name           email  midterm exam  final exam  overall score  \
# 1  Bar  br9876@foo.edu            64          72           68.8
# 2  Baz  bz2292@foo.edu            87          81           83.4
# 3  Bum  bm4567@foo.edu            64          59           61.0
#
#                                     comment
# 1  Your overall score in the course is 68.8
# 2  Your overall score in the course is 83.4
# 3  Your overall score in the course is 61.0

# %%
df.shape
# Out:
# (5, 6)

# %% [markdown]
# ## Getting a subset of a dataframe

# %% [markdown]
# Get a set of rows and columns by their indexes:

# %%
df.loc[ [1,2], ['name', 'overall score'] ]
# Out:
#   name  overall score
# 1  Bar           68.8
# 2  Baz           83.4

# %%
# a more verbose syntax for doing the same thing
df.loc[ [1,2] ][ ['name', 'overall score'] ]
# Out:
#   name  overall score
# 1  Bar           68.8
# 2  Baz           83.4

# %% [markdown]
# You can specify a range of rows and/or a range of columns:

# %%
df.loc[ 1:3, 'name':'midterm exam' ]
# Out:
#   name           email  midterm exam
# 1  Bar  br9876@foo.edu            64
# 2  Baz  bz2292@foo.edu            87
# 3  Bum  bm4567@foo.edu            64

# %% [markdown]
# Note that accessing rows and columns like this results a `DataFrame`, not a `Series`.

# %%
type(df.loc[ [1,2], ['name', 'overall score'] ])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Sorting

# %%
# sort by a column's value
df.sort_values(by='name', ascending=True)
# Out:
#      name           email  midterm exam  final exam  overall score  \
# 1     Bar  br9876@foo.edu            64          72           68.8
# 2     Baz  bz2292@foo.edu            87          81           83.4
# 4  Buddle   bp987@foo.edu            72          88           81.6
# 3     Bum  bm4567@foo.edu            64          59           61.0
# 0     Foo  fo1258@foo.edu            99          94           96.0
#
#                                     comment
# 1  Your overall score in the course is 68.8
# 2  Your overall score in the course is 83.4
# 4  Your overall score in the course is 81.6
# 3  Your overall score in the course is 61.0
# 0  Your overall score in the course is 96.0

# %%
# add a new row with the same name as an existing row, but a different email
new_row = pd.Series({ 
    'name': 'Baz', 
    'email': 'bz2289@foo.edu',
    'midterm exam': 88,
    'final exam': 74
})

# append and automatically assign an index to new row
df = df.append(new_row, ignore_index=True) 

# sort by primary and secondary columns
df.sort_values(by=['name', 'email'], ascending=True)
# Out:
#      name           email  midterm exam  final exam  overall score  \
# 1     Bar  br9876@foo.edu            64          72           68.8
# 5     Baz  bz2289@foo.edu            88          74            NaN
# 2     Baz  bz2292@foo.edu            87          81           83.4
# 4  Buddle   bp987@foo.edu            72          88           81.6
# 3     Bum  bm4567@foo.edu            64          59           61.0
# 0     Foo  fo1258@foo.edu            99          94           96.0
#
#                                     comment
# 1  Your overall score in the course is 68.8
# 5                                       NaN
# 2  Your overall score in the course is 83.4
# 4  Your overall score in the course is 81.6
# 3  Your overall score in the course is 61.0
# 0  Your overall score in the course is 96.0

# %%
# sort by index
df.sort_index(ascending=False)
# Out:
#      name           email  midterm exam  final exam  overall score  \
# 5     Baz  bz2289@foo.edu            88          74            NaN
# 4  Buddle   bp987@foo.edu            72          88           81.6
# 3     Bum  bm4567@foo.edu            64          59           61.0
# 2     Baz  bz2292@foo.edu            87          81           83.4
# 1     Bar  br9876@foo.edu            64          72           68.8
# 0     Foo  fo1258@foo.edu            99          94           96.0
#
#                                     comment
# 5                                       NaN
# 4  Your overall score in the course is 81.6
# 3  Your overall score in the course is 61.0
# 2  Your overall score in the course is 83.4
# 1  Your overall score in the course is 68.8
# 0  Your overall score in the course is 96.0

# %% [markdown]
# ## Filtering rows

# %%
# match a criterion
df[ df['name'] == 'Bar' ]
# Out:
#   name           email  midterm exam  final exam  overall score  \
# 1  Bar  br9876@foo.edu            64          72           68.8
#
#                                     comment
# 1  Your overall score in the course is 68.8

# %%
# match multiple criteria using & or | logic operators
df[ (df['name'] != 'Bar') & (df['midterm exam'] > 50) ]
# Out:
#      name           email  midterm exam  final exam  overall score  \
# 0     Foo  fo1258@foo.edu            99          94           96.0
# 2     Baz  bz2292@foo.edu            87          81           83.4
# 3     Bum  bm4567@foo.edu            64          59           61.0
# 4  Buddle   bp987@foo.edu            72          88           81.6
# 5     Baz  bz2289@foo.edu            88          74            NaN
#
#                                     comment
# 0  Your overall score in the course is 96.0
# 2  Your overall score in the course is 83.4
# 3  Your overall score in the course is 61.0
# 4  Your overall score in the course is 81.6
# 5                                       NaN

# %% [markdown]
# ## Filtering columns

# %% [markdown]
# Extracting a **single column** is straightforward with square bracket syntax.

# %%
# fetch the 'name' column - this returns a Series
df['name']
# Out:
# 0       Foo
# 1       Bar
# 2       Baz
# 3       Bum
# 4    Buddle
# 5       Baz
# Name: name, dtype: object

# %% [markdown]
# The easiest way to extract **multiple columns** from a dataframe is by supplying a list of column names.

# %%
# fetch the 'name' and 'final exam' columns - this returns a DataFrame
df[ ['name', 'final exam'] ]
# Out:
#      name  final exam
# 0     Foo          94
# 1     Bar          72
# 2     Baz          81
# 3     Bum          59
# 4  Buddle          88
# 5     Baz          74

# %% [markdown]
# ## Filtering rows and columns

# %% [markdown]
# It is possible to use two sets of brackets to perform both row and column filters in one expression.

# %%
# find one row by its index, and fetch one column from the results - this returns a single value
df.loc[2]['final exam']
# Out:
# 81

# %%
# filter rows by criteria, and fetch one column from the results - this returns a Series
df[ df['name'] != 'Baz'][ 'name' ]
# Out:
# 0       Foo
# 1       Bar
# 3       Bum
# 4    Buddle
# Name: name, dtype: object

# %%
# filter rows, and fetch multiple columns from the results - this returns a DataFrame
df[ df['name'] != 'Baz'][ ['name', 'midterm exam'] ]
# Out:
#      name  midterm exam
# 0     Foo            99
# 1     Bar            64
# 3     Bum            64
# 4  Buddle            72

# %% [markdown]
# ## Basic operations

# %%
# give a flat 2% curve to all students on the midterm exam
# update the midterm exam column
df['midterm exam'] = df['midterm exam'] + 2
df
# Out:
#      name           email  midterm exam  final exam  overall score  \
# 0     Foo  fo1258@foo.edu           101          94           96.0
# 1     Bar  br9876@foo.edu            66          72           68.8
# 2     Baz  bz2292@foo.edu            89          81           83.4
# 3     Bum  bm4567@foo.edu            66          59           61.0
# 4  Buddle   bp987@foo.edu            74          88           81.6
# 5     Baz  bz2289@foo.edu            90          74            NaN
#
#                                     comment
# 0  Your overall score in the course is 96.0
# 1  Your overall score in the course is 68.8
# 2  Your overall score in the course is 83.4
# 3  Your overall score in the course is 61.0
# 4  Your overall score in the course is 81.6
# 5                                       NaN

# %%
# add a new column to the dataframe...

# first, generate a Series of fake student ids
n_numbers = pd.Series(100000000 * np.random.random(7) ) # generate a series of random numbers
n_numbers = n_numbers.astype(int) # convert to a simple int to remove decimal place
n_numbers = 'N' + n_numbers.map(str) # add the letter 'N' in front of each number (first convert each to str)

# add to dataframe as a new column
df['n number'] = n_numbers
df
# Out:
#      name           email  midterm exam  final exam  overall score  \
# 0     Foo  fo1258@foo.edu           101          94           96.0
# 1     Bar  br9876@foo.edu            66          72           68.8
# 2     Baz  bz2292@foo.edu            89          81           83.4
# 3     Bum  bm4567@foo.edu            66          59           61.0
# 4  Buddle   bp987@foo.edu            74          88           81.6
# 5     Baz  bz2289@foo.edu            90          74            NaN
#
#                                     comment   n number
# 0  Your overall score in the course is 96.0  N37419271
# 1  Your overall score in the course is 68.8  N71172550
# 2  Your overall score in the course is 83.4   N7408211
# 3  Your overall score in the course is 61.0  N45718482
# 4  Your overall score in the course is 81.6  N58780095
# 5                                       NaN  N33025817

# %% [markdown]
# ## Merging two dataframes

# %%
# let's first create a second dataframe with some more information about each student
# note that one of the indices in this dataframe does not exist in the other dataframe
df2 = pd.DataFrame({
    'major': ['Math', 'Computer Science', 'Philosophy', 'Organic Gardening', 'Organic Gardening', 'Sociology'],
    'minor': ['Art History', 'Linguistics', 'Music Performance', 'Theater Lighting', 'Theater Lighting', 'Mathematics']
}, index = [3, 0, 2, 1, 4, 5])

df2
# Out:
#                major              minor
# 3               Math        Art History
# 0   Computer Science        Linguistics
# 2         Philosophy  Music Performance
# 1  Organic Gardening   Theater Lighting
# 4  Organic Gardening   Theater Lighting
# 5          Sociology        Mathematics

# %%
# do an "inner join" type merge, where referential integrity is maintained
df.join(df2)
# Out:
#      name           email  midterm exam  final exam  overall score  \
# 0     Foo  fo1258@foo.edu           101          94           96.0
# 1     Bar  br9876@foo.edu            66          72           68.8
# 2     Baz  bz2292@foo.edu            89          81           83.4
# 3     Bum  bm4567@foo.edu            66          59           61.0
# 4  Buddle   bp987@foo.edu            74          88           81.6
# 5     Baz  bz2289@foo.edu            90          74            NaN
#
#                                     comment   n number              major  \
# 0  Your overall score in the course is 96.0  N37419271   Computer Science
# 1  Your overall score in the course is 68.8  N71172550  Organic Gardening
# 2  Your overall score in the course is 83.4   N7408211         Philosophy
# 3  Your overall score in the course is 61.0  N45718482               Math
# 4  Your overall score in the course is 81.6  N58780095  Organic Gardening
# 5                                       NaN  N33025817          Sociology
#
#                minor
# 0        Linguistics
# 1   Theater Lighting
# 2  Music Performance
# 3        Art History
# 4   Theater Lighting
# 5        Mathematics

# %%
# do a "left join" type merge, where referential integrity is not maintained
pd.concat( [df, df2], axis=1)
# Out:
#      name           email  midterm exam  final exam  overall score  \
# 0     Foo  fo1258@foo.edu           101          94           96.0
# 1     Bar  br9876@foo.edu            66          72           68.8
# 2     Baz  bz2292@foo.edu            89          81           83.4
# 3     Bum  bm4567@foo.edu            66          59           61.0
# 4  Buddle   bp987@foo.edu            74          88           81.6
# 5     Baz  bz2289@foo.edu            90          74            NaN
#
#                                     comment   n number              major  \
# 0  Your overall score in the course is 96.0  N37419271   Computer Science
# 1  Your overall score in the course is 68.8  N71172550  Organic Gardening
# 2  Your overall score in the course is 83.4   N7408211         Philosophy
# 3  Your overall score in the course is 61.0  N45718482               Math
# 4  Your overall score in the course is 81.6  N58780095  Organic Gardening
# 5                                       NaN  N33025817          Sociology
#
#                minor
# 0        Linguistics
# 1   Theater Lighting
# 2  Music Performance
# 3        Art History
# 4   Theater Lighting
# 5        Mathematics

# %% [markdown]
# ## Setting the index
# It's possible to change which column is used as an index

# %%
# set the index to be the new n number
df.set_index('n number')
# Out:
#              name           email  midterm exam  final exam  overall score  \
# n number
# N37419271     Foo  fo1258@foo.edu           101          94           96.0
# N71172550     Bar  br9876@foo.edu            66          72           68.8
# N7408211      Baz  bz2292@foo.edu            89          81           83.4
# N45718482     Bum  bm4567@foo.edu            66          59           61.0
# N58780095  Buddle   bp987@foo.edu            74          88           81.6
# N33025817     Baz  bz2289@foo.edu            90          74            NaN
#
#                                             comment
# n number
# N37419271  Your overall score in the course is 96.0
# N71172550  Your overall score in the course is 68.8
# N7408211   Your overall score in the course is 83.4
# N45718482  Your overall score in the course is 61.0
# N58780095  Your overall score in the course is 81.6
# N33025817                                       NaN

# %% [markdown]
# ## Importing data from files
# Pandas can import from a variety of common data file formats, including CSV, JSON, fixed-width column text, and more.

# %%
# open data about NYC jobs from https://data.cityofnewyork.us/City-Government/NYC-Jobs/kpav-sd4t
df = pd.read_csv('./data/NYC_Jobs.csv')

# %%
# get the DataFrame's schema - notice the auto-detection of data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Job ID                         2823 non-null   int64
#  1   Agency                         2823 non-null   object
#  2   Posting Type                   2823 non-null   object
#  3   # Of Positions                 2823 non-null   int64
#  4   Business Title                 2823 non-null   object
#  5   Civil Service Title            2823 non-null   object
#  6   Title Classification           2823 non-null   object
#  7   Title Code No                  2823 non-null   object
#  8   Level                          2823 non-null   object
#  9   Job Category                   2821 non-null   object
#  10  Full-Time/Part-Time indicator  2680 non-null   object
#  11  Career Level                   2821 non-null   object
#  12  Salary Range From              2823 non-null   float64
#  13  Salary Range To                2823 non-null   float64
#  14  Salary Frequency               2823 non-null   object
#  15  Work Location                  2823 non-null   object
#  16  Division/Work Unit             2823 non-null   object
#  17  Job Description                2823 non-null   object
#  18  Minimum Qual Requirements      2810 non-null   object
#  19  Preferred Skills               2512 non-null   object
#  20  Additional Information         1809 non-null   object
#  21  To Apply                       2822 non-null   object
#  22  Hours/Shift                    742 non-null    object
#  23  Work Location 1                1276 non-null   object
#  24  Recruitment Contact            0 non-null      float64
#  25  Residency Requirement          2823 non-null   object
#  26  Posting Date                   2823 non-null   object
#  27  Post Until                     843 non-null    object
#  28  Posting Updated                2823 non-null   object
#  29  Process Date                   2823 non-null   object
# dtypes: float64(3), int64(2), object(25)
# memory usage: 661.8+ KB

# %%
# show a few randomly-sampled rows
df.sample(5)
# Out:
#       Job ID                          Agency Posting Type  # Of Positions  \
# 72    483730     TAXI & LIMOUSINE COMMISSION     External               2
# 1973  490660  DEPT OF ENVIRONMENT PROTECTION     Internal              23
# 1519  519921   OFFICE OF MANAGEMENT & BUDGET     Internal               1
# 1480  517184  HOUSING PRESERVATION & DVLPMNT     External               1
# 46    458082   DEPT OF HEALTH/MENTAL HYGIENE     Internal               1
#
#                                          Business Title  \
# 72                    Data Scientist - Policy Analytics
# 1973                          Engineering Technician II
# 1519  Summer Undergraduate Intern  Community Board R...
# 1480                        Director, Brooklyn Planning
# 46                             City Custodial Assistant
#
#                 Civil Service Title Title Classification Title Code No Level  \
# 72          CITY RESEARCH SCIENTIST    Non-Competitive-5         21744    02
# 1973         ENGINEERING TECHNICIAN        Competitive-1         20113    02
# 1519          SUMMER COLLEGE INTERN    Non-Competitive-5         10234    00
# 1480  ASSOCIATE HOUSING DEVELOPMENT        Competitive-1         22508    00
# 46         CITY CUSTODIAL ASSISTANT              Labor-3         90644    00
#
#                                            Job Category  ...  \
# 72    Technology, Data & Innovation Policy, Research...  ...
# 1973              Engineering, Architecture, & Planning  ...
# 1519                 Finance, Accounting, & Procurement  ...
# 1480              Engineering, Architecture, & Planning  ...
# 46             Health Building Operations & Maintenance  ...
#
#                                  Additional Information  \
# 72                                                  NaN
# 1973  Appointments are subject to OMB approval. For ...
# 1519  REQUIREMENTS:  Undergraduate interns should ha...
# 1480                                                NaN
# 46    **IMPORTANT NOTES TO ALL CANDIDATES:  Please n...
#
#                                                To Apply  Hours/Shift  \
# 72    Click, APPLY NOW Current city employees must a...          NaN
# 1973                         Click the Apply Now button          NaN
# 1519  Please go to www.nyc.gov/careers and search fo...          NaN
# 1480                                      Apply online.          NaN
# 46    Apply online with a cover letter to https://a1...          NaN
#
#                 Work Location 1 Recruitment Contact  \
# 72    33 Beaver St, New York NY                 NaN
# 1973                        NaN                 NaN
# 1519       255 Greenwich Street                 NaN
# 1480            100 Gold Street                 NaN
# 46                          NaN                 NaN
#
#                                   Residency Requirement Posting Date  \
# 72    New York City residency is generally required ...   09/13/2021
# 1973  New York City residency is generally required ...   10/08/2021
# 1519  You must be legally eligible to work in the Un...   02/09/2022
# 1480  New York City residency is generally required ...   01/25/2022
# 46    New York City residency is generally required ...   01/05/2022
#
#        Post Until Posting Updated Process Date
# 72            NaN      09/14/2021   02/15/2022
# 1973          NaN      10/21/2021   02/15/2022
# 1519          NaN      02/09/2022   02/15/2022
# 1480  24-FEB-2022      01/25/2022   02/15/2022
# 46    05-MAY-2022      01/05/2022   02/15/2022
#
# [5 rows x 30 columns]

# %%
# look for good-paying jobs ( > $200,000) available for external candidates
df_external_jobs = df[ df['Posting Type'] == 'External' ]
df_external_annual_jobs = df_external_jobs[ df_external_jobs['Salary Frequency'] == 'Annual' ]
df_external_annual_jobs_over_200k = df_external_annual_jobs[ df_external_annual_jobs['Salary Range To'] >= 200000 ]
df_external_annual_jobs_over_200k.sample(5)
# Out:
#       Job ID                         Agency Posting Type  # Of Positions  \
# 521   440527   NYC EMPLOYEES RETIREMENT SYS     External               1
# 1625  468218       DEPARTMENT OF CORRECTION     External               1
# 1953  502421  OFFICE OF MANAGEMENT & BUDGET     External               1
# 1782  520572      OFFICE OF LABOR RELATIONS     External               1
# 1788  468476          NYC HOUSING AUTHORITY     External               1
#
#                                      Business Title  \
# 521               ADMINISTRATIVE MANAGEMENT AUDITOR
# 1625                                General Counsel
# 1953                  Assistant Director  Education
# 1782                                General Counsel
# 1788  Director of Public Housing Tenancy Operations
#
#                  Civil Service Title      Title Classification Title Code No  \
# 521   ADMINISTRATIVE MANAGEMENT AUDI             Competitive-1         10010
# 1625       DEPUTY COMMISSIONER (DOC)         Non-Competitive-5         95043
# 1953  BUDGET ANALYST (OMB)-MANAGERIA  Pending Classification-2         0608A
# 1782                   COUNSEL (OLR)         Non-Competitive-5         30100
# 1788  ADMINISTRATIVE HOUSING MANAGER             Competitive-1         10018
#
#      Level                                       Job Category  ...  \
# 521     M5                   Administration & Human Resources  ...
# 1625    M5                                      Legal Affairs  ...
# 1953    M4  Finance, Accounting, & Procurement Policy, Res...  ...
# 1782    M6                                      Legal Affairs  ...
# 1788    M4                        Policy, Research & Analysis  ...
#
#                                  Additional Information  \
# 521                                                 NaN
# 1625                                                NaN
# 1953  REQUIREMENTS:  Assistant Director ($141,766): ...
# 1782  The salary being offered is $180,000 to $230,0...
# 1788  Preference will be given to employees who have...
#
#                                                To Apply  Hours/Shift  \
# 521   TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...          NaN
# 1625  For City employees: Go to Employee Self-Servic...          NaN
# 1953  For City employees, please go to Employee Self...          NaN
# 1782  To apply please submit your resume and cover l...          NaN
# 1788                        Click the Apply Now button.          NaN
#
#            Work Location 1 Recruitment Contact  \
# 521                    NaN                 NaN
# 1625                   NaN                 NaN
# 1953  255 Greenwich Street                 NaN
# 1782                   NaN                 NaN
# 1788                   NaN                 NaN
#
#                                   Residency Requirement Posting Date  \
# 521   New York City residency is generally required ...   06/24/2020
# 1625  New York City residency is generally required ...   07/13/2021
# 1953  New York City residency is generally required ...   11/19/2021
# 1782  New York City residency is generally required ...   02/14/2022
# 1788               NYCHA has no residency requirements.   08/04/2021
#
#        Post Until Posting Updated Process Date
# 521           NaN      07/07/2020   02/15/2022
# 1625          NaN      07/13/2021   02/15/2022
# 1953          NaN      11/19/2021   02/15/2022
# 1782  22-FEB-2022      02/14/2022   02/15/2022
# 1788          NaN      08/30/2021   02/15/2022
#
# [5 rows x 30 columns]

# %%
df_external_annual_jobs_over_200k[ ["Business Title", "Salary Range From", "Salary Range To"] ].sort_values(by="Salary Range To", ascending=False).head(5)
# Out:
#                                   Business Title  Salary Range From  \
# 2615     Head, Real Estate Investments Portfolio           250000.0
# 2288                          Chief Risk Officer           250000.0
# 2671  Assistant to the Deputy Borough President.            58700.0
# 1837                  Assistant to the Ptesident            58700.0
# 397                          Deputy Commissioner           106729.0
#
#       Salary Range To
# 2615         265000.0
# 2288         265000.0
# 2671         252165.0
# 1837         252165.0
# 397          241434.0

# %%
# the same query as above, just in one line
df[ (df['Posting Type'] == 'External') & (df['Salary Frequency'] == 'Annual') & (df['Salary Range To'] >= 200000) ].sample(5)
# Out:
#       Job ID                        Agency Posting Type  # Of Positions  \
# 642   373748  NYC EMPLOYEES RETIREMENT SYS     External               1
# 1782  520572     OFFICE OF LABOR RELATIONS     External               1
# 2525  519718  DEPARTMENT OF TRANSPORTATION     External               1
# 1063  441706   TAXI & LIMOUSINE COMMISSION     External               1
# 2402  453677  NYC EMPLOYEES RETIREMENT SYS     External               1
#
#                                          Business Title  \
# 642                   ADMINISTRATIVE MANAGEMENT AUDITOR
# 1782                                    General Counsel
# 2525  Assistant Commissioner - Office of Special Events
# 1063  General Counsel/Deputy Commissioner for Legal ...
# 2402                  ADMINISTRATIVE MANAGEMENT AUDITOR
#
#                  Civil Service Title Title Classification Title Code No Level  \
# 642   ADMINISTRATIVE MANAGEMENT AUDI        Competitive-1         10010    M7
# 1782                   COUNSEL (OLR)    Non-Competitive-5         30100    M6
# 2525  ADMINISTRATIVE COMMUNITY RELAT        Competitive-1         10022    M4
# 1063        EXECUTIVE AGENCY COUNSEL    Non-Competitive-5         95005    M6
# 2402  ADMINISTRATIVE MANAGEMENT AUDI        Competitive-1         10010    M5
#
#                                            Job Category  ...  \
# 642   Administration & Human Resources Finance, Acco...  ...
# 1782                                      Legal Affairs  ...
# 2525  Administration & Human Resources Constituent S...  ...
# 1063                                      Legal Affairs  ...
# 2402                   Administration & Human Resources  ...
#
#                                  Additional Information  \
# 642                                                 NaN
# 1782  The salary being offered is $180,000 to $230,0...
# 2525  ***In order to be considered for this position...
# 1063  As of August 2, 2021, all new hires must be va...
# 2402                                                NaN
#
#                                                To Apply        Hours/Shift  \
# 642   TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...                NaN
# 1782  To apply please submit your resume and cover l...                NaN
# 2525  ***In order to be considered for this position...  Mon-Fri 9am - 5pm
# 1063  Click, APPLY NOW Current city employees must a...                NaN
# 2402  TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...                NaN
#
#                 Work Location 1 Recruitment Contact  \
# 642                         NaN                 NaN
# 1782                        NaN                 NaN
# 2525          55 Water St Ny Ny                 NaN
# 1063  33 Beaver St, New York Ny                 NaN
# 2402                        NaN                 NaN
#
#                                   Residency Requirement Posting Date  \
# 642   New York City residency is generally required ...   11/07/2018
# 1782  New York City residency is generally required ...   02/14/2022
# 2525  New York City residency is generally required ...   02/10/2022
# 1063  New York City residency is generally required ...   07/13/2020
# 2402  New York City residency is generally required ...   11/17/2020
#
#        Post Until Posting Updated Process Date
# 642           NaN      11/07/2018   02/15/2022
# 1782  22-FEB-2022      02/14/2022   02/15/2022
# 2525  23-FEB-2022      02/11/2022   02/15/2022
# 1063          NaN      08/16/2021   02/15/2022
# 2402          NaN      11/17/2020   02/15/2022
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Deal with missing values

# %%
# find any rows with missing values
bad_rows = df[ df.isnull().any(axis=1) ]
bad_rows.head(3)
# Out:
#    Job ID                          Agency Posting Type  # Of Positions  \
# 0  517168  HOUSING PRESERVATION & DVLPMNT     External               1
# 1  501645       ADMIN FOR CHILDREN'S SVCS     Internal               2
# 2  520016    NYC EMPLOYEES RETIREMENT SYS     External               1
#
#                               Business Title            Civil Service Title  \
# 0  Deputy Director, Pre-Development Planning  ASSOCIATE HOUSING DEVELOPMENT
# 1                 Senior Stationary Engineer     SENIOR STATIONARY ENGINEER
# 2      Disability Case Management Supervisor          COMMUNITY COORDINATOR
#
#   Title Classification Title Code No Level  \
# 0        Competitive-1         22508    00
# 1        Competitive-1         91638    00
# 2    Non-Competitive-5         56058    00
#
#                                         Job Category  ...  \
# 0              Engineering, Architecture, & Planning  ...
# 1  Building Operations & Maintenance Social Services  ...
# 2  Constituent Services & Community Programs Comm...  ...
#
#                               Additional Information  \
# 0                                                NaN
# 1  Section 424-A of the New York Social Services ...
# 2                                                NaN
#
#                                             To Apply  Hours/Shift  \
# 0                                      Apply online.          NaN
# 1                       Click on the Apply to button          NaN
# 2  TO APPLY FOR CONSIDERATION, PLEASE FORWARD A C...          NaN
#
#    Work Location 1 Recruitment Contact  \
# 0  100 Gold Street                 NaN
# 1              NaN                 NaN
# 2              NaN                 NaN
#
#                                Residency Requirement Posting Date  \
# 0  New York City residency is generally required ...   01/25/2022
# 1  New York City Residency is not required for th...   02/04/2022
# 2  New York City residency is generally required ...   02/10/2022
#
#     Post Until Posting Updated Process Date
# 0  24-FEB-2022      01/25/2022   02/15/2022
# 1  06-MAR-2022      02/04/2022   02/15/2022
# 2  25-FEB-2022      02/10/2022   02/15/2022
#
# [3 rows x 30 columns]

# %%
# drop a few rows with missing data manually
new_df = df.drop( df.index[ [0, 1, 2] ] )

# look for missing values again
bad_rows = new_df[ new_df.isnull().any(axis=1) ]
bad_rows.head(3)
# Out:
#    Job ID                      Agency Posting Type  # Of Positions  \
# 3  515139             FIRE DEPARTMENT     Internal               4
# 4  497303  DEPT OF PARKS & RECREATION     Internal               1
# 5  497303  DEPT OF PARKS & RECREATION     Internal               1
#
#           Business Title             Civil Service Title Title Classification  \
# 3       Chief Dispatcher  SUPERVISING FIRE ALARM DISPATC        Competitive-1
# 4  Recreation Supervisor           RECREATION SUPERVISOR        Competitive-1
# 5  Recreation Supervisor           RECREATION SUPERVISOR        Competitive-1
#
#   Title Code No Level                                Job Category  ...  \
# 3         71060    02  Communications & Intergovernmental Affairs  ...
# 4         60440    00   Constituent Services & Community Programs  ...
# 5         60440    00   Constituent Services & Community Programs  ...
#
#                               Additional Information  \
# 3  NOTE: This position is open to qualified perso...
# 4  Fees: Hired candidates will be subject to a pr...
# 5  Fees: Hired candidates will be subject to a pr...
#
#                                             To Apply  \
# 3  CITY EMPLOYEES MUST APPLY VIA EMPLOYEE SELF SE...
# 4  Please submit a cover letter and resume.  Park...
# 5  Please submit a cover letter and resume.  Park...
#
#                                          Hours/Shift  \
# 3  Supervising Fire Alarm Dispatchers may be requ...
# 4                                                NaN
# 5                                                NaN
#
#                                 Work Location 1 Recruitment Contact  \
# 3             Fire Dispatch Operations - PSAC 1                 NaN
# 4  Jackie Robinson Recreation Center, Manhattan                 NaN
# 5  Jackie Robinson Recreation Center, Manhattan                 NaN
#
#                                Residency Requirement Posting Date  \
# 3  New York City residency is generally required ...   02/03/2022
# 4  Residency in New York City, Nassau, Orange, Ro...   02/11/2022
# 5  Residency in New York City, Nassau, Orange, Ro...   02/11/2022
#
#     Post Until Posting Updated Process Date
# 3  24-FEB-2022      02/03/2022   02/15/2022
# 4  11-MAR-2022      02/11/2022   02/15/2022
# 5  11-MAR-2022      02/11/2022   02/15/2022
#
# [3 rows x 30 columns]

# %%
# drop rows with any missing values
new_df.dropna()
# Out:
# Empty DataFrame
# Columns: [Job ID, Agency, Posting Type, # Of Positions, Business Title, Civil Service Title, Title Classification, Title Code No, Level, Job Category, Full-Time/Part-Time indicator, Career Level, Salary Range From, Salary Range To, Salary Frequency, Work Location, Division/Work Unit, Job Description, Minimum Qual Requirements, Preferred Skills, Additional Information, To Apply, Hours/Shift, Work Location 1, Recruitment Contact, Residency Requirement, Posting Date, Post Until, Posting Updated, Process Date]
# Index: []
#
# [0 rows x 30 columns]

# %%
# oops... we were too aggressive.  Let's drop just those rows with missing salary info
df = df.dropna(subset=['Salary Range From', 'Salary Range To'])
df.sample(3)
# Out:
#       Job ID                          Agency Posting Type  # Of Positions  \
# 1217  442559           NYC HOUSING AUTHORITY     Internal             100
# 564   517984  DEPT OF ENVIRONMENT PROTECTION     Internal               3
# 2016  511510     HRA/DEPT OF SOCIAL SERVICES     Internal               1
#
#               Business Title Civil Service Title Title Classification  \
# 1217        CARETAKER X (HA)      CARETAKER (HA)              Labor-3
# 564   Clerical Associate III  CLERICAL ASSOCIATE        Competitive-1
# 2016              TIMEKEEPER  CLERICAL ASSOCIATE        Competitive-1
#
#      Title Code No Level                                      Job Category  \
# 1217         90645    00                 Building Operations & Maintenance
# 564          10251    03                  Administration & Human Resources
# 2016         10251    04  Administration & Human Resources Social Services
#
#       ...                             Additional Information  \
# 1217  ...           NYCHA residents are encouraged to apply.
# 564   ...  Appointments are subject to OMB approval.  For...
# 2016  ...  The federal government provides student loan f...
#
#                                                To Apply  Hours/Shift  \
# 1217                        Click the Apply Now button.          NaN
# 564                    To Apply: Click Apply Now button     35 hours
# 2016  CANDIDATE MUST BE PERMANENT IN THE CLERICAL AS...          NaN
#
#                                         Work Location 1 Recruitment Contact  \
# 1217                                                NaN                 NaN
# 564   Various Locations at Wastewater Treatment Plan...                 NaN
# 2016                         33 Beaver St, New York, NY                 NaN
#
#                                   Residency Requirement Posting Date  \
# 1217               NYCHA has no residency requirements.   09/04/2020
# 564   New York City residency is generally required ...   02/04/2022
# 2016  New York City residency is generally required ...   12/23/2021
#
#        Post Until Posting Updated Process Date
# 1217          NaN      09/04/2020   02/15/2022
# 564   18-FEB-2022      02/04/2022   02/15/2022
# 2016  25-FEB-2022      02/11/2022   02/15/2022
#
# [3 rows x 30 columns]

# %%
# fill in missing values with zeros
df = df.fillna(0)
df.sample(3)
# Out:
#       Job ID                          Agency Posting Type  # Of Positions  \
# 834   495413  OFFICE OF EMERGENCY MANAGEMENT     Internal               1
# 1053  509209        DEPARTMENT FOR THE AGING     Internal               1
# 2238  474116   DEPT OF DESIGN & CONSTRUCTION     Internal               1
#
#                            Business Title             Civil Service Title  \
# 834           HEALTH & MEDICAL SPECIALIST  EMERGENCY PREPAREDNESS SPECIAL
# 1053  Data Accuracy Specialist (Per-Diem)         CITY RESEARCH SCIENTIST
# 2238             Capital Payments Auditor                      ACCOUNTANT
#
#           Title Classification Title Code No Level  \
# 834   Pending Classification-2         06766    01
# 1053         Non-Competitive-5         21744    03
# 2238             Competitive-1         40510    02
#
#                                      Job Category  ...  \
# 834                                        Health  ...
# 1053  Policy, Research & Analysis Social Services  ...
# 2238           Finance, Accounting, & Procurement  ...
#
#                                  Additional Information  \
# 834   New York City Emergency Management (NYCEM) hel...
# 1053  This Per Diem position is full-time (35 hours ...
# 2238                                                  0
#
#                                                To Apply        Hours/Shift  \
# 834   Current City Employees: Apply via Employee Sel...  Monday-Friday 9-5
# 1053  Please be sure to submit a resume & cover lett...                  0
# 2238  For City Employees, please go to Employee Self...           35 Hours
#
#                                Work Location 1 Recruitment Contact  \
# 834   165 Cadman Plaza East Brooklyn, NY 11201                 0.0
# 1053                                         0                 0.0
# 2238             30-30 Thomson Avenue, LIC, NY                 0.0
#
#                                   Residency Requirement Posting Date  \
# 834   New York City residency is generally required ...   11/15/2021
# 1053  New York City residency is generally required ...   02/09/2022
# 2238  New York City residency is generally required ...   12/22/2021
#
#        Post Until Posting Updated Process Date
# 834             0      11/16/2021   02/15/2022
# 1053  10-MAY-2022      02/09/2022   02/15/2022
# 2238  27-FEB-2022      01/28/2022   02/15/2022
#
# [3 rows x 30 columns]

# %% [markdown]
# ## Basic statistics

# %%
# get an overview of most common stats
df.describe()
# Out:
#               Job ID  # Of Positions  Salary Range From  Salary Range To  \
# count    2823.000000     2823.000000        2823.000000      2823.000000
# mean   484959.478215        2.733971       63866.675553     88589.563539
# std     51846.706525       11.006525       33002.429986     46742.505962
# min     87990.000000        1.000000           0.000000        15.450000
# 25%    471473.000000        1.000000       49950.000000     62215.000000
# 50%    502085.000000        1.000000       62397.000000     83981.000000
# 75%    514317.500000        1.000000       79620.000000    110000.000000
# max    520640.000000      250.000000      250000.000000    265000.000000
#
#        Recruitment Contact
# count               2823.0
# mean                   0.0
# std                    0.0
# min                    0.0
# 25%                    0.0
# 50%                    0.0
# 75%                    0.0
# max                    0.0

# %%
# the same, but just for the 'Salary Range To' field (which is a Series, of course)
df['Salary Range To'].describe()
# Out:
# count      2823.000000
# mean      88589.563539
# std       46742.505962
# min          15.450000
# 25%       62215.000000
# 50%       83981.000000
# 75%      110000.000000
# max      265000.000000
# Name: Salary Range To, dtype: float64

# %%
# get just the mean from the column
df['Salary Range To'].median()
# Out:
# 83981.0

# %% [markdown]
# The other statistics functions - `min()`, `max()`, `mean()`, `std()`, `count()` - work similarly.

# %% [markdown]
# ## Count values
# The `value_counts()` function of a Series returns the number of times each value occurs.

# %%
df['Career Level'].value_counts()
# Out:
# Experienced (non-manager)    1933
# Manager                       385
# Entry-Level                   362
# Executive                      80
# Student                        61
# 0                               2
# Name: Career Level, dtype: int64

# %%
df['Full-Time/Part-Time indicator'].value_counts()
# Out:
# F    2551
# 0     143
# P     129
# Name: Full-Time/Part-Time indicator, dtype: int64

# %% [markdown]
# ## Grouping by a column

# %%
# count how many jobs are in each agency
df.groupby("Agency")['Agency'].count()
# Out:
# Agency
# ADMIN FOR CHILDREN'S SVCS          27
# ADMIN TRIALS AND HEARINGS          28
# BOROUGH PRESIDENT-QUEENS            4
# BUSINESS INTEGRITY COMMISSION       7
# CIVILIAN COMPLAINT REVIEW BD       17
# CONFLICTS OF INTEREST BOARD         8
# CONSUMER AFFAIRS                   48
# DEPARTMENT FOR THE AGING           26
# DEPARTMENT OF BUILDINGS            15
# DEPARTMENT OF BUSINESS SERV.        8
# DEPARTMENT OF CITY PLANNING        27
# DEPARTMENT OF CORRECTION          213
# DEPARTMENT OF FINANCE              31
# DEPARTMENT OF INVESTIGATION        24
# DEPARTMENT OF PROBATION             6
# DEPARTMENT OF SANITATION           32
# DEPARTMENT OF TRANSPORTATION      161
# DEPT OF CITYWIDE ADMIN SVCS        37
# DEPT OF DESIGN & CONSTRUCTION      55
# DEPT OF ENVIRONMENT PROTECTION    356
# DEPT OF HEALTH/MENTAL HYGIENE     203
# DEPT OF INFO TECH & TELECOMM       27
# DEPT OF PARKS & RECREATION         66
# DEPT OF YOUTH & COMM DEV SRVS      29
# DEPT. OF HOMELESS SERVICES          2
# DISTRICT ATTORNEY KINGS COUNTY      4
# DISTRICT ATTORNEY RICHMOND COU     18
# EQUAL EMPLOY PRACTICES COMM         2
# FINANCIAL INFO SVCS AGENCY         98
# FIRE DEPARTMENT                    25
# HOUSING PRESERVATION & DVLPMNT    130
# HRA/DEPT OF SOCIAL SERVICES        35
# HUMAN RIGHTS COMMISSION            60
# LANDMARKS PRESERVATION COMM         4
# LAW DEPARTMENT                    144
# MANHATTAN COMMUNITY BOARD #11       2
# MANHATTAN COMMUNITY BOARD #8        2
# MAYORS OFFICE OF CONTRACT SVCS      4
# NYC EMPLOYEES RETIREMENT SYS       84
# NYC FIRE PENSION FUND               2
# NYC HOUSING AUTHORITY             241
# NYC POLICE PENSION FUND             9
# OFF OF PAYROLL ADMINISTRATION      17
# OFFICE OF EMERGENCY MANAGEMENT     17
# OFFICE OF LABOR RELATIONS           2
# OFFICE OF MANAGEMENT & BUDGET     158
# OFFICE OF THE COMPTROLLER          52
# POLICE DEPARTMENT                  78
# PRESIDENT BOROUGH OF MANHATTAN      2
# PUBLIC ADMINISTRATOR-NEW YORK       3
# TAXI & LIMOUSINE COMMISSION       146
# TEACHERS RETIREMENT SYSTEM         27
# Name: Agency, dtype: int64

# %%
# calculate the mean top salary within each agency
df.groupby("Agency")['Salary Range To'].mean()
# Out:
# Agency
# ADMIN FOR CHILDREN'S SVCS          75985.334815
# ADMIN TRIALS AND HEARINGS          52919.282857
# BOROUGH PRESIDENT-QUEENS          252165.000000
# BUSINESS INTEGRITY COMMISSION      87857.142857
# CIVILIAN COMPLAINT REVIEW BD       81148.529412
# CONFLICTS OF INTEREST BOARD        73727.500000
# CONSUMER AFFAIRS                   80520.537500
# DEPARTMENT FOR THE AGING           50468.342308
# DEPARTMENT OF BUILDINGS            75645.866667
# DEPARTMENT OF BUSINESS SERV.      128485.375000
# DEPARTMENT OF CITY PLANNING        82946.000000
# DEPARTMENT OF CORRECTION           96335.074123
# DEPARTMENT OF FINANCE              94341.318065
# DEPARTMENT OF INVESTIGATION        78847.250000
# DEPARTMENT OF PROBATION            72848.333333
# DEPARTMENT OF SANITATION           62130.343750
# DEPARTMENT OF TRANSPORTATION      107995.890497
# DEPT OF CITYWIDE ADMIN SVCS        88593.827027
# DEPT OF DESIGN & CONSTRUCTION     110570.036364
# DEPT OF ENVIRONMENT PROTECTION     94913.979372
# DEPT OF HEALTH/MENTAL HYGIENE      59583.404684
# DEPT OF INFO TECH & TELECOMM      116225.518519
# DEPT OF PARKS & RECREATION         64274.677470
# DEPT OF YOUTH & COMM DEV SRVS      86191.750055
# DEPT. OF HOMELESS SERVICES        109409.000000
# DISTRICT ATTORNEY KINGS COUNTY    102500.000000
# DISTRICT ATTORNEY RICHMOND COU     88514.666667
# EQUAL EMPLOY PRACTICES COMM        81203.000000
# FINANCIAL INFO SVCS AGENCY        107349.044898
# FIRE DEPARTMENT                    80512.817600
# HOUSING PRESERVATION & DVLPMNT     88925.761538
# HRA/DEPT OF SOCIAL SERVICES        75244.942857
# HUMAN RIGHTS COMMISSION            75184.530363
# LANDMARKS PRESERVATION COMM       107500.000000
# LAW DEPARTMENT                     82824.636928
# MANHATTAN COMMUNITY BOARD #11      60000.000000
# MANHATTAN COMMUNITY BOARD #8       42500.000000
# MAYORS OFFICE OF CONTRACT SVCS    112500.000000
# NYC EMPLOYEES RETIREMENT SYS      122217.108648
# NYC FIRE PENSION FUND             192152.000000
# NYC HOUSING AUTHORITY             102768.778755
# NYC POLICE PENSION FUND           105158.333333
# OFF OF PAYROLL ADMINISTRATION      65541.105882
# OFFICE OF EMERGENCY MANAGEMENT     71823.529412
# OFFICE OF LABOR RELATIONS         231974.000000
# OFFICE OF MANAGEMENT & BUDGET      77274.867089
# OFFICE OF THE COMPTROLLER         111008.448846
# POLICE DEPARTMENT                  65983.648205
# PRESIDENT BOROUGH OF MANHATTAN     60000.000000
# PUBLIC ADMINISTRATOR-NEW YORK      49331.666667
# TAXI & LIMOUSINE COMMISSION        82059.235855
# TEACHERS RETIREMENT SYSTEM         71668.037037
# Name: Salary Range To, dtype: float64

# %%
# show just the top 10 paying agencies
df.groupby("Agency")['Salary Range To'].mean().sort_values().tail(10)
# Out:
# Agency
# DEPT. OF HOMELESS SERVICES        109409.000000
# DEPT OF DESIGN & CONSTRUCTION     110570.036364
# OFFICE OF THE COMPTROLLER         111008.448846
# MAYORS OFFICE OF CONTRACT SVCS    112500.000000
# DEPT OF INFO TECH & TELECOMM      116225.518519
# NYC EMPLOYEES RETIREMENT SYS      122217.108648
# DEPARTMENT OF BUSINESS SERV.      128485.375000
# NYC FIRE PENSION FUND             192152.000000
# OFFICE OF LABOR RELATIONS         231974.000000
# BOROUGH PRESIDENT-QUEENS          252165.000000
# Name: Salary Range To, dtype: float64

# %%
# find agencies with the largest range of salaries
df['Salary Range'] = df['Salary Range To'] - df['Salary Range From']
df.groupby("Agency")['Salary Range'].mean().sort_values().tail(10)[::-1]
# Out:
# Agency
# BOROUGH PRESIDENT-QUEENS         193465.000000
# OFFICE OF LABOR RELATIONS        134144.000000
# NYC FIRE PENSION FUND            120114.000000
# DEPARTMENT OF BUSINESS SERV.      72978.000000
# DEPT OF INFO TECH & TELECOMM      55328.702222
# DEPT OF DESIGN & CONSTRUCTION     45076.872727
# DEPARTMENT OF TRANSPORTATION      44444.558509
# NYC EMPLOYEES RETIREMENT SYS      43930.259740
# FINANCIAL INFO SVCS AGENCY        38006.085306
# NYC HOUSING AUTHORITY             37707.622407
# Name: Salary Range, dtype: float64

# %% [markdown]
# ## Shape

# %%
# how many rows and columns?
df.shape
# Out:
# (2823, 31)

# %%
# remind ourselves of the look of the data
df.sample(3)
# Out:
#       Job ID                         Agency Posting Type  # Of Positions  \
# 1915  470130       DEPARTMENT OF CORRECTION     External               1
# 2048  510370   NYC EMPLOYEES RETIREMENT SYS     External               1
# 1397  519059  DEPT OF DESIGN & CONSTRUCTION     External               1
#
#                                          Business Title  \
# 1915              Director of Data Analytics & Research
# 2048  ADMINISTRATIVE RETIREMENTS BENEFITS SPECIALIST...
# 1397                                 Engineer-In-Charge
#
#                  Civil Service Title Title Classification Title Code No Level  \
# 1915         CITY RESEARCH SCIENTIST    Non-Competitive-5         21744    4A
# 2048  ADMINISTRATIVE RETIREMENTS BEN        Competitive-1         8298C    00
# 1397                  CIVIL ENGINEER        Competitive-1         20215    02
#
#                                Job Category  ...  \
# 1915          Technology, Data & Innovation  ...
# 2048          Technology, Data & Innovation  ...
# 1397  Engineering, Architecture, & Planning  ...
#
#                                                To Apply Hours/Shift  \
# 1915  For City employees: Go to Employee Self-Servic...           0
# 2048  NYCERS is an Equal Opportunity Employer Intern...           0
# 1397  For City Employees, please go to Employee Self...    35 Hours
#
#                                        Work Location 1  Recruitment Contact  \
# 1915                                                 0                  0.0
# 2048                                                 0                  0.0
# 1397  30-30 Thomson Avenue, Long Island City, NY 11101                  0.0
#
#                                   Residency Requirement Posting Date  \
# 1915  New York City residency is generally required ...   07/27/2021
# 2048  New York City residency is generally required ...   12/21/2021
# 1397  New York City Residency is not required for th...   02/04/2022
#
#        Post Until Posting Updated Process Date Salary Range
# 1915            0      07/27/2021   02/15/2022      14143.0
# 2048            0      12/22/2021   02/15/2022      15000.0
# 1397  05-MAY-2022      02/07/2022   02/15/2022      31360.0
#
# [3 rows x 31 columns]

# %%
# flip the dataframe so columns become rows and rows become columns
df.transpose().head()
# Out:
#                                                      0     \
# Job ID                                             517168
# Agency                     HOUSING PRESERVATION & DVLPMNT
# Posting Type                                     External
# # Of Positions                                          1
# Business Title  Deputy Director, Pre-Development Planning
#
#                                       1     \
# Job ID                              501645
# Agency           ADMIN FOR CHILDREN'S SVCS
# Posting Type                      Internal
# # Of Positions                           2
# Business Title  Senior Stationary Engineer
#
#                                                  2                 3     \
# Job ID                                         520016            515139
# Agency                   NYC EMPLOYEES RETIREMENT SYS   FIRE DEPARTMENT
# Posting Type                                 External          Internal
# # Of Positions                                      1                 4
# Business Title  Disability Case Management Supervisor  Chief Dispatcher
#
#                                       4                           5     \
# Job ID                              497303                      497303
# Agency          DEPT OF PARKS & RECREATION  DEPT OF PARKS & RECREATION
# Posting Type                      Internal                    Internal
# # Of Positions                           1                           1
# Business Title       Recreation Supervisor       Recreation Supervisor
#
#                                             6     \
# Job ID                                    460742
# Agency                     NYC HOUSING AUTHORITY
# Posting Type                            External
# # Of Positions                                 3
# Business Title  Environmental Compliance Analyst
#
#                                           7                         8     \
# Job ID                                  465916                    462614
# Agency           DEPT OF HEALTH/MENTAL HYGIENE  DEPARTMENT OF CORRECTION
# Posting Type                          Internal                  External
# # Of Positions                               1                         8
# Business Title  Environmental Health Scientist           Agency Attorney
#
#                                    9     ...                      2813  \
# Job ID                           496445  ...                    435593
# Agency            NYC HOUSING AUTHORITY  ...  DEPARTMENT OF CORRECTION
# Posting Type                   External  ...                  Internal
# # Of Positions                        1  ...                         1
# Business Title  AGENCY ATTORNEY INTERNE  ...            Policy Analyst
#
#                                       2814                          2815  \
# Job ID                              507116                        496359
# Agency          TEACHERS RETIREMENT SYSTEM  DEPARTMENT OF TRANSPORTATION
# Posting Type                      External                      Internal
# # Of Positions                           1                             1
# Business Title             Agency Attorney   Associate Project Manager 3
#
#                                        2816  \
# Job ID                               518449
# Agency          TAXI & LIMOUSINE COMMISSION
# Posting Type                       Internal
# # Of Positions                            1
# Business Title       Database Administrator
#
#                                                              2817  \
# Job ID                                                     508500
# Agency                                   DEPARTMENT FOR THE AGING
# Posting Type                                             Internal
# # Of Positions                                                  1
# Business Title  Senior Director of Budgets, Project Management...
#
#                                                              2818  \
# Job ID                                                     483210
# Agency                                 DEPT OF PARKS & RECREATION
# Posting Type                                             Internal
# # Of Positions                                                  1
# Business Title  Landscape Architect for Forestry, Horticulture...
#
#                                                2819  \
# Job ID                                       518950
# Agency                        NYC HOUSING AUTHORITY
# Posting Type                               External
# # Of Positions                                    1
# Business Title  Board Committee Meeting Coordinator
#
#                                       2820                               2821  \
# Job ID                              484984                             520249
# Agency          FINANCIAL INFO SVCS AGENCY                  POLICE DEPARTMENT
# Posting Type                      External                           Internal
# # Of Positions                           1                                  1
# Business Title     FMS ARCHITECT/DEVELOPER  Senior Police Administrative Aide
#
#                                       2822
# Job ID                              518700
# Agency                   POLICE DEPARTMENT
# Posting Type                      Internal
# # Of Positions                           1
# Business Title  Police Administrative Aide
#
# [5 rows x 2823 columns]
